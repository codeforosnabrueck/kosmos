# %%
import pandas as pd
import numpy as np
import seaborn
import matplotlib.pyplot as plt
import seaborn as sns
from plotnine import *
import altair as alt

# %%
df = pd.read_csv('Ziel 3 - Nachhaltige Mobilität.csv')
df.head()
# Out:
#              Stadtbereich Nachhaltige Mobilitätskonzepte Unnamed: 2  \
# 0                     NaN              Carsharing Nutzer        NaN
# 1                     NaN                           2012       2013
# 2  Stadt Osnabrück gesamt                            737        960
# 3              Innenstadt                              -          -
# 4               Weststadt                              -          -
#
#   Unnamed: 3 Unnamed: 4 Unnamed: 5                   Unnamed: 6 Unnamed: 7  \
# 0        NaN        NaN        NaN  Anzahl Carsharing Fahrzeuge        NaN
# 1       2014       2015       2016                         2012       2013
# 2       1436       1860       2409                           41         49
# 3          -          -          -                            -          -
# 4          -          -          -                            -          -
#
#   Unnamed: 8 Unnamed: 9                   ...                     \
# 0        NaN        NaN                   ...
# 1       2014       2015                   ...
# 2         69         86                   ...
# 3          -          -                   ...
# 4          -          -                   ...
#
#           Unnamed: 50        Unnamed: 51        Unnamed: 52  \
# 0                 NaN                NaN                NaN
# 1                2012               2013               2014
# 2  479,24347255189133  484,2567410543241  490,7526989580329
# 3                   -                  -                  -
# 4                   -                  -                  -
#
#          Unnamed: 53         Unnamed: 54                Unnamed: 55  \
# 0                NaN                 NaN  Durchschnitt PKW/Haushalt
# 1               2015                2016                       2014
# 2  478,9199174182332  482,54780100508486                       0,77
# 3                  -                   -                       0,37
# 4                  -                   -                       0,72
#
#   Unnamed: 56 Unnamed: 57 Unnamed: 58                              Unnamed: 59
# 0         NaN         NaN         NaN  Anteil ÖPNV an den Verkehrsmitteln in %
# 1        2015        2016        2017                                     2013
# 2        0,78        0,79         0,8                                        8
# 3        0,38        0,38         0,4                                        -
# 4        0,71        0,73        0,72                                        -
#
# [5 rows x 60 columns]

# %%
# df = pd.read_csv('Excel_Export_Ziel3.csv')
# df.head()

# %%
df.iloc[0] = df.iloc[0].ffill()
df.head()
# Out:
#              Stadtbereich Nachhaltige Mobilitätskonzepte         Unnamed: 2  \
# 0                     NaN              Carsharing Nutzer  Carsharing Nutzer
# 1                     NaN                           2012               2013
# 2  Stadt Osnabrück gesamt                            737                960
# 3              Innenstadt                              -                  -
# 4               Weststadt                              -                  -
#
#           Unnamed: 3         Unnamed: 4         Unnamed: 5  \
# 0  Carsharing Nutzer  Carsharing Nutzer  Carsharing Nutzer
# 1               2014               2015               2016
# 2               1436               1860               2409
# 3                  -                  -                  -
# 4                  -                  -                  -
#
#                     Unnamed: 6                   Unnamed: 7  \
# 0  Anzahl Carsharing Fahrzeuge  Anzahl Carsharing Fahrzeuge
# 1                         2012                         2013
# 2                           41                           49
# 3                            -                            -
# 4                            -                            -
#
#                     Unnamed: 8                   Unnamed: 9  \
# 0  Anzahl Carsharing Fahrzeuge  Anzahl Carsharing Fahrzeuge
# 1                         2014                         2015
# 2                           69                           86
# 3                            -                            -
# 4                            -                            -
#
#                     ...                                 Unnamed: 50  \
# 0                   ...                     PKW-Dichte (Pkw/1000EW)
# 1                   ...                                        2012
# 2                   ...                          479,24347255189133
# 3                   ...                                           -
# 4                   ...                                           -
#
#                Unnamed: 51              Unnamed: 52              Unnamed: 53  \
# 0  PKW-Dichte (Pkw/1000EW)  PKW-Dichte (Pkw/1000EW)  PKW-Dichte (Pkw/1000EW)
# 1                     2013                     2014                     2015
# 2        484,2567410543241        490,7526989580329        478,9199174182332
# 3                        -                        -                        -
# 4                        -                        -                        -
#
#                Unnamed: 54                Unnamed: 55  \
# 0  PKW-Dichte (Pkw/1000EW)  Durchschnitt PKW/Haushalt
# 1                     2016                       2014
# 2       482,54780100508486                       0,77
# 3                        -                       0,37
# 4                        -                       0,72
#
#                  Unnamed: 56                Unnamed: 57  \
# 0  Durchschnitt PKW/Haushalt  Durchschnitt PKW/Haushalt
# 1                       2015                       2016
# 2                       0,78                       0,79
# 3                       0,38                       0,38
# 4                       0,71                       0,73
#
#                  Unnamed: 58                              Unnamed: 59
# 0  Durchschnitt PKW/Haushalt  Anteil ÖPNV an den Verkehrsmitteln in %
# 1                       2017                                     2013
# 2                        0,8                                        8
# 3                        0,4                                        -
# 4                       0,72                                        -
#
# [5 rows x 60 columns]

# %%
df = df.iloc[:3, 1:]
df
# Out:
#   Nachhaltige Mobilitätskonzepte         Unnamed: 2         Unnamed: 3  \
# 0              Carsharing Nutzer  Carsharing Nutzer  Carsharing Nutzer
# 1                           2012               2013               2014
# 2                            737                960               1436
#
#           Unnamed: 4         Unnamed: 5                   Unnamed: 6  \
# 0  Carsharing Nutzer  Carsharing Nutzer  Anzahl Carsharing Fahrzeuge
# 1               2015               2016                         2012
# 2               1860               2409                           41
#
#                     Unnamed: 7                   Unnamed: 8  \
# 0  Anzahl Carsharing Fahrzeuge  Anzahl Carsharing Fahrzeuge
# 1                         2013                         2014
# 2                           49                           69
#
#                     Unnamed: 9                  Unnamed: 10  \
# 0  Anzahl Carsharing Fahrzeuge  Anzahl Carsharing Fahrzeuge
# 1                         2015                         2016
# 2                           86                           79
#
#                     ...                                 Unnamed: 50  \
# 0                   ...                     PKW-Dichte (Pkw/1000EW)
# 1                   ...                                        2012
# 2                   ...                          479,24347255189133
#
#                Unnamed: 51              Unnamed: 52              Unnamed: 53  \
# 0  PKW-Dichte (Pkw/1000EW)  PKW-Dichte (Pkw/1000EW)  PKW-Dichte (Pkw/1000EW)
# 1                     2013                     2014                     2015
# 2        484,2567410543241        490,7526989580329        478,9199174182332
#
#                Unnamed: 54                Unnamed: 55  \
# 0  PKW-Dichte (Pkw/1000EW)  Durchschnitt PKW/Haushalt
# 1                     2016                       2014
# 2       482,54780100508486                       0,77
#
#                  Unnamed: 56                Unnamed: 57  \
# 0  Durchschnitt PKW/Haushalt  Durchschnitt PKW/Haushalt
# 1                       2015                       2016
# 2                       0,78                       0,79
#
#                  Unnamed: 58                              Unnamed: 59
# 0  Durchschnitt PKW/Haushalt  Anteil ÖPNV an den Verkehrsmitteln in %
# 1                       2017                                     2013
# 2                        0,8                                        8
#
# [3 rows x 59 columns]

# %%
detailgoal = pd.Series(df.columns)
detailgoal[detailgoal.str.startswith('Unnamed')] = None
detailgoal = detailgoal.ffill()
detailgoal.tail()
# Out:
# 54    Weiteres
# 55    Weiteres
# 56    Weiteres
# 57    Weiteres
# 58    Weiteres
# dtype: object

# %%
data = pd.DataFrame({
    'Detailziel': detailgoal,
    'Kennzahl': df.iloc[0].reset_index(drop=True),
    'Jahr': df.iloc[1].reset_index(drop=True),
    'Wert': df.iloc[2].reset_index(drop=True),
})

data
# Out:
#                                  Detailziel  \
# 0            Nachhaltige Mobilitätskonzepte
# 1            Nachhaltige Mobilitätskonzepte
# 2            Nachhaltige Mobilitätskonzepte
# 3            Nachhaltige Mobilitätskonzepte
# 4            Nachhaltige Mobilitätskonzepte
# 5            Nachhaltige Mobilitätskonzepte
# 6            Nachhaltige Mobilitätskonzepte
# 7            Nachhaltige Mobilitätskonzepte
# 8            Nachhaltige Mobilitätskonzepte
# 9            Nachhaltige Mobilitätskonzepte
# 10           Nachhaltige Mobilitätskonzepte
# 11           Nachhaltige Mobilitätskonzepte
# 12           Nachhaltige Mobilitätskonzepte
# 13           Nachhaltige Mobilitätskonzepte
# 14           Nachhaltige Mobilitätskonzepte
# 15                      E-Mobilität fördern
# 16                      E-Mobilität fördern
# 17                       Radverkehr stärken
# 18                       Radverkehr stärken
# 19                       Radverkehr stärken
# 20                       Radverkehr stärken
# 21                       Radverkehr stärken
# 22                       Radverkehr stärken
# 23                       Radverkehr stärken
# 24                       Radverkehr stärken
# 25                       Radverkehr stärken
# 26  Öffentlichen Personennahverkehr fördern
# 27  Öffentlichen Personennahverkehr fördern
# 28  Öffentlichen Personennahverkehr fördern
# 29  Öffentlichen Personennahverkehr fördern
# 30  Öffentlichen Personennahverkehr fördern
# 31  Öffentlichen Personennahverkehr fördern
# 32  Öffentlichen Personennahverkehr fördern
# 33  Öffentlichen Personennahverkehr fördern
# 34                                 Weiteres
# 35                                 Weiteres
# 36                                 Weiteres
# 37                                 Weiteres
# 38                                 Weiteres
# 39                                 Weiteres
# 40                                 Weiteres
# 41                                 Weiteres
# 42                                 Weiteres
# 43                                 Weiteres
# 44                                 Weiteres
# 45                                 Weiteres
# 46                                 Weiteres
# 47                                 Weiteres
# 48                                 Weiteres
# 49                                 Weiteres
# 50                                 Weiteres
# 51                                 Weiteres
# 52                                 Weiteres
# 53                                 Weiteres
# 54                                 Weiteres
# 55                                 Weiteres
# 56                                 Weiteres
# 57                                 Weiteres
# 58                                 Weiteres
#
#                                              Kennzahl  Jahr  \
# 0                                   Carsharing Nutzer  2012
# 1                                   Carsharing Nutzer  2013
# 2                                   Carsharing Nutzer  2014
# 3                                   Carsharing Nutzer  2015
# 4                                   Carsharing Nutzer  2016
# 5                         Anzahl Carsharing Fahrzeuge  2012
# 6                         Anzahl Carsharing Fahrzeuge  2013
# 7                         Anzahl Carsharing Fahrzeuge  2014
# 8                         Anzahl Carsharing Fahrzeuge  2015
# 9                         Anzahl Carsharing Fahrzeuge  2016
# 10                        Anzahl Carsharing Standorte  2012
# 11                        Anzahl Carsharing Standorte  2013
# 12                        Anzahl Carsharing Standorte  2014
# 13                        Anzahl Carsharing Standorte  2015
# 14                        Anzahl Carsharing Standorte  2016
# 15               Anteil zugelassener E-Fahrzeuge in %  2017
# 16  Anteil zugelassener Plug-In Hybride am Gesamtb...  2017
# 17      Anteil Radverkehr an den Verkehrsmitteln in %  2013
# 18  Anzahl Fahrradunfälle  mit leichtverletzten Pe...  2013
# 19  Anzahl Fahrradunfälle  mit leichtverletzten Pe...  2014
# 20  Anzahl Fahrradunfälle  mit leichtverletzten Pe...  2015
# 21  Anzahl Fahrradunfälle  mit leichtverletzten Pe...  2016
# 22  Anzahl Fahrradunfälle  mit schwerverletzten Pe...  2013
# 23  Anzahl Fahrradunfälle  mit schwerverletzten Pe...  2014
# 24  Anzahl Fahrradunfälle  mit schwerverletzten Pe...  2015
# 25  Anzahl Fahrradunfälle  mit schwerverletzten Pe...  2016
# 26                         Beförderte Personen (ÖPNV)  2011
# 27                         Beförderte Personen (ÖPNV)  2012
# 28                         Beförderte Personen (ÖPNV)  2013
# 29                         Beförderte Personen (ÖPNV)  2014
# 30                         Beförderte Personen (ÖPNV)  2015
# 31                         Beförderte Personen (ÖPNV)  2016
# 32  Anzahl der Personen, die sehr und eher zufried...  2015
# 33  Anzahl der Personen, die eher unzufrieden und ...  2015
# 34             Anteil PKW an den Verkehrsmitteln in %  2013
# 35       Anteil Fußgänger an den Verkehrsmitteln in %  2013
# 36  Anzahl der Verkehrsunfälle in der Stadt Osnabrück  2010
# 37  Anzahl der Verkehrsunfälle in der Stadt Osnabrück  2011
# 38  Anzahl der Verkehrsunfälle in der Stadt Osnabrück  2012
# 39  Anzahl der Verkehrsunfälle in der Stadt Osnabrück  2013
# 40  Anzahl der Verkehrsunfälle in der Stadt Osnabrück  2014
# 41  Anzahl der Verkehrsunfälle in der Stadt Osnabrück  2015
# 42  Anzahl der Verkehrsunfälle in der Stadt Osnabrück  2016
# 43   Anzahl der Fahrradunfälle in der Stadt Osnabrück  2013
# 44   Anzahl der Fahrradunfälle in der Stadt Osnabrück  2014
# 45   Anzahl der Fahrradunfälle in der Stadt Osnabrück  2015
# 46   Anzahl der Fahrradunfälle in der Stadt Osnabrück  2016
# 47                            PKW-Dichte (Pkw/1000EW)  2010
# 48                            PKW-Dichte (Pkw/1000EW)  2011
# 49                            PKW-Dichte (Pkw/1000EW)  2012
# 50                            PKW-Dichte (Pkw/1000EW)  2013
# 51                            PKW-Dichte (Pkw/1000EW)  2014
# 52                            PKW-Dichte (Pkw/1000EW)  2015
# 53                            PKW-Dichte (Pkw/1000EW)  2016
# 54                          Durchschnitt PKW/Haushalt  2014
# 55                          Durchschnitt PKW/Haushalt  2015
# 56                          Durchschnitt PKW/Haushalt  2016
# 57                          Durchschnitt PKW/Haushalt  2017
# 58            Anteil ÖPNV an den Verkehrsmitteln in %  2013
#
#                   Wert
# 0                  737
# 1                  960
# 2                 1436
# 3                 1860
# 4                 2409
# 5                   41
# 6                   49
# 7                   69
# 8                   86
# 9                   79
# 10                  36
# 11                  42
# 12                  44
# 13                  47
# 14                  50
# 15                0,06
# 16                0,03
# 17                  20
# 18                 241
# 19                 253
# 20                 259
# 21                 274
# 22                  33
# 23                  50
# 24                  52
# 25                  49
# 26            35596801
# 27            35438793
# 28            35681996
# 29            35539657
# 30            36075670
# 31            36305605
# 32                 370
# 33                 111
# 34                  48
# 35                  24
# 36                5060
# 37                5117
# 38                5165
# 39                5331
# 40                5268
# 41                5217
# 42                4904
# 43                 390
# 44                 431
# 45                 434
# 46                 443
# 47  472,02013474396085
# 48   475,1155123913292
# 49  479,24347255189133
# 50   484,2567410543241
# 51   490,7526989580329
# 52   478,9199174182332
# 53  482,54780100508486
# 54                0,77
# 55                0,78
# 56                0,79
# 57                 0,8
# 58                   8

# %%
data['Jahr'] = pd.to_datetime(data['Jahr'].astype(str).str[:4])

# %%
try:
    data['Wert'] = pd.to_numeric(data['Wert'].astype(str))
except ValueError:
    data['Wert'] = data['Wert'].astype(str).str.replace(',', '')
    data['Wert'] = pd.to_numeric(data['Wert'])

data
# Out:
#                                  Detailziel  \
# 0            Nachhaltige Mobilitätskonzepte
# 1            Nachhaltige Mobilitätskonzepte
# 2            Nachhaltige Mobilitätskonzepte
# 3            Nachhaltige Mobilitätskonzepte
# 4            Nachhaltige Mobilitätskonzepte
# 5            Nachhaltige Mobilitätskonzepte
# 6            Nachhaltige Mobilitätskonzepte
# 7            Nachhaltige Mobilitätskonzepte
# 8            Nachhaltige Mobilitätskonzepte
# 9            Nachhaltige Mobilitätskonzepte
# 10           Nachhaltige Mobilitätskonzepte
# 11           Nachhaltige Mobilitätskonzepte
# 12           Nachhaltige Mobilitätskonzepte
# 13           Nachhaltige Mobilitätskonzepte
# 14           Nachhaltige Mobilitätskonzepte
# 15                      E-Mobilität fördern
# 16                      E-Mobilität fördern
# 17                       Radverkehr stärken
# 18                       Radverkehr stärken
# 19                       Radverkehr stärken
# 20                       Radverkehr stärken
# 21                       Radverkehr stärken
# 22                       Radverkehr stärken
# 23                       Radverkehr stärken
# 24                       Radverkehr stärken
# 25                       Radverkehr stärken
# 26  Öffentlichen Personennahverkehr fördern
# 27  Öffentlichen Personennahverkehr fördern
# 28  Öffentlichen Personennahverkehr fördern
# 29  Öffentlichen Personennahverkehr fördern
# 30  Öffentlichen Personennahverkehr fördern
# 31  Öffentlichen Personennahverkehr fördern
# 32  Öffentlichen Personennahverkehr fördern
# 33  Öffentlichen Personennahverkehr fördern
# 34                                 Weiteres
# 35                                 Weiteres
# 36                                 Weiteres
# 37                                 Weiteres
# 38                                 Weiteres
# 39                                 Weiteres
# 40                                 Weiteres
# 41                                 Weiteres
# 42                                 Weiteres
# 43                                 Weiteres
# 44                                 Weiteres
# 45                                 Weiteres
# 46                                 Weiteres
# 47                                 Weiteres
# 48                                 Weiteres
# 49                                 Weiteres
# 50                                 Weiteres
# 51                                 Weiteres
# 52                                 Weiteres
# 53                                 Weiteres
# 54                                 Weiteres
# 55                                 Weiteres
# 56                                 Weiteres
# 57                                 Weiteres
# 58                                 Weiteres
#
#                                              Kennzahl       Jahr  \
# 0                                   Carsharing Nutzer 2012-01-01
# 1                                   Carsharing Nutzer 2013-01-01
# 2                                   Carsharing Nutzer 2014-01-01
# 3                                   Carsharing Nutzer 2015-01-01
# 4                                   Carsharing Nutzer 2016-01-01
# 5                         Anzahl Carsharing Fahrzeuge 2012-01-01
# 6                         Anzahl Carsharing Fahrzeuge 2013-01-01
# 7                         Anzahl Carsharing Fahrzeuge 2014-01-01
# 8                         Anzahl Carsharing Fahrzeuge 2015-01-01
# 9                         Anzahl Carsharing Fahrzeuge 2016-01-01
# 10                        Anzahl Carsharing Standorte 2012-01-01
# 11                        Anzahl Carsharing Standorte 2013-01-01
# 12                        Anzahl Carsharing Standorte 2014-01-01
# 13                        Anzahl Carsharing Standorte 2015-01-01
# 14                        Anzahl Carsharing Standorte 2016-01-01
# 15               Anteil zugelassener E-Fahrzeuge in % 2017-01-01
# 16  Anteil zugelassener Plug-In Hybride am Gesamtb... 2017-01-01
# 17      Anteil Radverkehr an den Verkehrsmitteln in % 2013-01-01
# 18  Anzahl Fahrradunfälle  mit leichtverletzten Pe... 2013-01-01
# 19  Anzahl Fahrradunfälle  mit leichtverletzten Pe... 2014-01-01
# 20  Anzahl Fahrradunfälle  mit leichtverletzten Pe... 2015-01-01
# 21  Anzahl Fahrradunfälle  mit leichtverletzten Pe... 2016-01-01
# 22  Anzahl Fahrradunfälle  mit schwerverletzten Pe... 2013-01-01
# 23  Anzahl Fahrradunfälle  mit schwerverletzten Pe... 2014-01-01
# 24  Anzahl Fahrradunfälle  mit schwerverletzten Pe... 2015-01-01
# 25  Anzahl Fahrradunfälle  mit schwerverletzten Pe... 2016-01-01
# 26                         Beförderte Personen (ÖPNV) 2011-01-01
# 27                         Beförderte Personen (ÖPNV) 2012-01-01
# 28                         Beförderte Personen (ÖPNV) 2013-01-01
# 29                         Beförderte Personen (ÖPNV) 2014-01-01
# 30                         Beförderte Personen (ÖPNV) 2015-01-01
# 31                         Beförderte Personen (ÖPNV) 2016-01-01
# 32  Anzahl der Personen, die sehr und eher zufried... 2015-01-01
# 33  Anzahl der Personen, die eher unzufrieden und ... 2015-01-01
# 34             Anteil PKW an den Verkehrsmitteln in % 2013-01-01
# 35       Anteil Fußgänger an den Verkehrsmitteln in % 2013-01-01
# 36  Anzahl der Verkehrsunfälle in der Stadt Osnabrück 2010-01-01
# 37  Anzahl der Verkehrsunfälle in der Stadt Osnabrück 2011-01-01
# 38  Anzahl der Verkehrsunfälle in der Stadt Osnabrück 2012-01-01
# 39  Anzahl der Verkehrsunfälle in der Stadt Osnabrück 2013-01-01
# 40  Anzahl der Verkehrsunfälle in der Stadt Osnabrück 2014-01-01
# 41  Anzahl der Verkehrsunfälle in der Stadt Osnabrück 2015-01-01
# 42  Anzahl der Verkehrsunfälle in der Stadt Osnabrück 2016-01-01
# 43   Anzahl der Fahrradunfälle in der Stadt Osnabrück 2013-01-01
# 44   Anzahl der Fahrradunfälle in der Stadt Osnabrück 2014-01-01
# 45   Anzahl der Fahrradunfälle in der Stadt Osnabrück 2015-01-01
# 46   Anzahl der Fahrradunfälle in der Stadt Osnabrück 2016-01-01
# 47                            PKW-Dichte (Pkw/1000EW) 2010-01-01
# 48                            PKW-Dichte (Pkw/1000EW) 2011-01-01
# 49                            PKW-Dichte (Pkw/1000EW) 2012-01-01
# 50                            PKW-Dichte (Pkw/1000EW) 2013-01-01
# 51                            PKW-Dichte (Pkw/1000EW) 2014-01-01
# 52                            PKW-Dichte (Pkw/1000EW) 2015-01-01
# 53                            PKW-Dichte (Pkw/1000EW) 2016-01-01
# 54                          Durchschnitt PKW/Haushalt 2014-01-01
# 55                          Durchschnitt PKW/Haushalt 2015-01-01
# 56                          Durchschnitt PKW/Haushalt 2016-01-01
# 57                          Durchschnitt PKW/Haushalt 2017-01-01
# 58            Anteil ÖPNV an den Verkehrsmitteln in % 2013-01-01
#
#                  Wert
# 0                 737
# 1                 960
# 2                1436
# 3                1860
# 4                2409
# 5                  41
# 6                  49
# 7                  69
# 8                  86
# 9                  79
# 10                 36
# 11                 42
# 12                 44
# 13                 47
# 14                 50
# 15                  6
# 16                  3
# 17                 20
# 18                241
# 19                253
# 20                259
# 21                274
# 22                 33
# 23                 50
# 24                 52
# 25                 49
# 26           35596801
# 27           35438793
# 28           35681996
# 29           35539657
# 30           36075670
# 31           36305605
# 32                370
# 33                111
# 34                 48
# 35                 24
# 36               5060
# 37               5117
# 38               5165
# 39               5331
# 40               5268
# 41               5217
# 42               4904
# 43                390
# 44                431
# 45                434
# 46                443
# 47  47202013474396085
# 48   4751155123913292
# 49  47924347255189133
# 50   4842567410543241
# 51   4907526989580329
# 52   4789199174182332
# 53  48254780100508486
# 54                 77
# 55                 78
# 56                 79
# 57                  8
# 58                  8

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Data columns (total 4 columns):
# Detailziel    59 non-null object
# Kennzahl      59 non-null object
# Jahr          59 non-null datetime64[ns]
# Wert          59 non-null int64
# dtypes: datetime64[ns](1), int64(1), object(2)
# memory usage: 1.9+ KB

# %% [markdown]
# Turn each indicator into it's own column.

# %%
data = data.pivot(index='Jahr', columns='Kennzahl', values='Wert')
data
# Out:
# Kennzahl    Anteil Fußgänger an den Verkehrsmitteln in %  \
# Jahr
# 2010-01-01                                           NaN
# 2011-01-01                                           NaN
# 2012-01-01                                           NaN
# 2013-01-01                                          24.0
# 2014-01-01                                           NaN
# 2015-01-01                                           NaN
# 2016-01-01                                           NaN
# 2017-01-01                                           NaN
#
# Kennzahl    Anteil PKW an den Verkehrsmitteln in %  \
# Jahr
# 2010-01-01                                     NaN
# 2011-01-01                                     NaN
# 2012-01-01                                     NaN
# 2013-01-01                                    48.0
# 2014-01-01                                     NaN
# 2015-01-01                                     NaN
# 2016-01-01                                     NaN
# 2017-01-01                                     NaN
#
# Kennzahl    Anteil Radverkehr an den Verkehrsmitteln in %  \
# Jahr
# 2010-01-01                                            NaN
# 2011-01-01                                            NaN
# 2012-01-01                                            NaN
# 2013-01-01                                           20.0
# 2014-01-01                                            NaN
# 2015-01-01                                            NaN
# 2016-01-01                                            NaN
# 2017-01-01                                            NaN
#
# Kennzahl    Anteil zugelassener E-Fahrzeuge in %  \
# Jahr
# 2010-01-01                                   NaN
# 2011-01-01                                   NaN
# 2012-01-01                                   NaN
# 2013-01-01                                   NaN
# 2014-01-01                                   NaN
# 2015-01-01                                   NaN
# 2016-01-01                                   NaN
# 2017-01-01                                   6.0
#
# Kennzahl    Anteil zugelassener Plug-In Hybride am Gesamtbestand in %  \
# Jahr
# 2010-01-01                                                NaN
# 2011-01-01                                                NaN
# 2012-01-01                                                NaN
# 2013-01-01                                                NaN
# 2014-01-01                                                NaN
# 2015-01-01                                                NaN
# 2016-01-01                                                NaN
# 2017-01-01                                                3.0
#
# Kennzahl    Anteil ÖPNV an den Verkehrsmitteln in %  \
# Jahr
# 2010-01-01                                      NaN
# 2011-01-01                                      NaN
# 2012-01-01                                      NaN
# 2013-01-01                                      8.0
# 2014-01-01                                      NaN
# 2015-01-01                                      NaN
# 2016-01-01                                      NaN
# 2017-01-01                                      NaN
#
# Kennzahl    Anzahl Carsharing Fahrzeuge  Anzahl Carsharing Standorte  \
# Jahr
# 2010-01-01                          NaN                          NaN
# 2011-01-01                          NaN                          NaN
# 2012-01-01                         41.0                         36.0
# 2013-01-01                         49.0                         42.0
# 2014-01-01                         69.0                         44.0
# 2015-01-01                         86.0                         47.0
# 2016-01-01                         79.0                         50.0
# 2017-01-01                          NaN                          NaN
#
# Kennzahl    Anzahl Fahrradunfälle  mit leichtverletzten Personen  \
# Jahr
# 2010-01-01                                                NaN
# 2011-01-01                                                NaN
# 2012-01-01                                                NaN
# 2013-01-01                                              241.0
# 2014-01-01                                              253.0
# 2015-01-01                                              259.0
# 2016-01-01                                              274.0
# 2017-01-01                                                NaN
#
# Kennzahl    Anzahl Fahrradunfälle  mit schwerverletzten Personen  \
# Jahr
# 2010-01-01                                                NaN
# 2011-01-01                                                NaN
# 2012-01-01                                                NaN
# 2013-01-01                                               33.0
# 2014-01-01                                               50.0
# 2015-01-01                                               52.0
# 2016-01-01                                               49.0
# 2017-01-01                                                NaN
#
# Kennzahl    Anzahl der Fahrradunfälle in der Stadt Osnabrück  \
# Jahr
# 2010-01-01                                               NaN
# 2011-01-01                                               NaN
# 2012-01-01                                               NaN
# 2013-01-01                                             390.0
# 2014-01-01                                             431.0
# 2015-01-01                                             434.0
# 2016-01-01                                             443.0
# 2017-01-01                                               NaN
#
# Kennzahl    Anzahl der Personen, die eher unzufrieden und überhaupt nicht zufrieden mit dem öffentlichem Nahverkehr sind  \
# Jahr
# 2010-01-01                                                NaN
# 2011-01-01                                                NaN
# 2012-01-01                                                NaN
# 2013-01-01                                                NaN
# 2014-01-01                                                NaN
# 2015-01-01                                              111.0
# 2016-01-01                                                NaN
# 2017-01-01                                                NaN
#
# Kennzahl    Anzahl der Personen, die sehr und eher zufrieden mit dem öffentlichem Nahverkehr sind  \
# Jahr
# 2010-01-01                                                NaN
# 2011-01-01                                                NaN
# 2012-01-01                                                NaN
# 2013-01-01                                                NaN
# 2014-01-01                                                NaN
# 2015-01-01                                              370.0
# 2016-01-01                                                NaN
# 2017-01-01                                                NaN
#
# Kennzahl    Anzahl der Verkehrsunfälle in der Stadt Osnabrück  \
# Jahr
# 2010-01-01                                             5060.0
# 2011-01-01                                             5117.0
# 2012-01-01                                             5165.0
# 2013-01-01                                             5331.0
# 2014-01-01                                             5268.0
# 2015-01-01                                             5217.0
# 2016-01-01                                             4904.0
# 2017-01-01                                                NaN
#
# Kennzahl    Beförderte Personen (ÖPNV)  Carsharing Nutzer  \
# Jahr
# 2010-01-01                         NaN                NaN
# 2011-01-01                  35596801.0                NaN
# 2012-01-01                  35438793.0              737.0
# 2013-01-01                  35681996.0              960.0
# 2014-01-01                  35539657.0             1436.0
# 2015-01-01                  36075670.0             1860.0
# 2016-01-01                  36305605.0             2409.0
# 2017-01-01                         NaN                NaN
#
# Kennzahl    Durchschnitt PKW/Haushalt  PKW-Dichte (Pkw/1000EW)
# Jahr
# 2010-01-01                        NaN             4.720201e+16
# 2011-01-01                        NaN             4.751155e+15
# 2012-01-01                        NaN             4.792435e+16
# 2013-01-01                        NaN             4.842567e+15
# 2014-01-01                       77.0             4.907527e+15
# 2015-01-01                       78.0             4.789199e+15
# 2016-01-01                       79.0             4.825478e+16
# 2017-01-01                        8.0                      NaN

# %%
import warnings

with warnings.catch_warnings():
    warnings.simplefilter("ignore")

    for kennzahl in data.columns:
        (ggplot(data, aes(x='data.index', y=kennzahl))
                 + geom_point(color='red', na_rm=True)
                 + geom_line(color='red')
                 + geom_smooth(method='lm')
                 + xlab('Jahr')
                 + scale_x_date(date_breaks='1 year', date_labels='%Y')
        ).draw()

# %%
corr = data.corr()
# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
fig, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# ## Looking at the trends

# %%
#dictionary that assigns the desired trend direction for each variable
trend_dict = {key: None for key in data.columns}
#all variables which we want to see rise over time:
trend_dict['Anteil Fußgänger an den Verkehrsmitteln in %'] = 'positive'
trend_dict['Anteil Radverkehr an den Verkehrsmitteln in %'] = 'positive'
trend_dict['Anteil zugelassener E-Fahrzeuge in %'] = 'positive'
trend_dict['Anteil zugelassener Plug-In Hybride am Gesamtbestand in %'] = 'positive'
trend_dict['Anteil ÖPNV an den Verkehrsmitteln in %'] = 'positive'
trend_dict['Anzahl Carsharing Fahrzeuge'] = 'positive'
trend_dict['Anzahl Carsharing Standorte'] = 'positive'
trend_dict['Anzahl der Personen, die sehr und eher zufrieden mit dem öffentlichem Nahverkehr sind'] = 'positive'
trend_dict['Beförderte Personen (ÖPNV)'] = 'positive'
trend_dict['Carsharing Nutzer'] = 'positive'

#all variables which we want to see diminish over time
trend_dict['Anteil PKW an den Verkehrsmitteln in %'] = 'negative'
trend_dict['Anzahl Fahrradunfälle  mit leichtverletzten Personen'] = 'negative'
trend_dict['Anzahl Fahrradunfälle  mit schwerverletzten Personen'] = 'negative'
trend_dict['Anzahl der Fahrradunfälle in der Stadt Osnabrück'] = 'negative'
trend_dict['Anzahl der Personen, die eher unzufrieden und überhaupt nicht zufrieden mit dem öffentlichem Nahverkehr sind'] = 'negative'
trend_dict['Anzahl der Verkehrsunfälle in der Stadt Osnabrück'] = 'negative'

# These things do not have an unambiguous interpretation.
trend_dict['Durchschnitt PKW/Haushalt'] = 'neutral'
trend_dict['PKW-Dichte (Pkw/1000EW)'] = 'neutral'

trend_dict
# Out:
# {'Anteil Fußgänger an den Verkehrsmitteln in %': 'positive',
#  'Anteil PKW an den Verkehrsmitteln in %': 'negative',
#  'Anteil Radverkehr an den Verkehrsmitteln in %': 'positive',
#  'Anteil zugelassener E-Fahrzeuge in %': 'positive',
#  'Anteil zugelassener Plug-In Hybride am Gesamtbestand in %': 'positive',
#  'Anteil ÖPNV an den Verkehrsmitteln in %': 'positive',
#  'Anzahl Carsharing Fahrzeuge': 'positive',
#  'Anzahl Carsharing Standorte': 'positive',
#  'Anzahl Fahrradunfälle  mit leichtverletzten Personen': 'negative',
#  'Anzahl Fahrradunfälle  mit schwerverletzten Personen': 'negative',
#  'Anzahl der Fahrradunfälle in der Stadt Osnabrück': 'negative',
#  'Anzahl der Personen, die eher unzufrieden und überhaupt nicht zufrieden mit dem öffentlichem Nahverkehr sind': 'negative',
#  'Anzahl der Personen, die sehr und eher zufrieden mit dem öffentlichem Nahverkehr sind': 'positive',
#  'Anzahl der Verkehrsunfälle in der Stadt Osnabrück': 'negative',
#  'Beförderte Personen (ÖPNV)': 'positive',
#  'Carsharing Nutzer': 'positive',
#  'Durchschnitt PKW/Haushalt': 'neutral',
#  'PKW-Dichte (Pkw/1000EW)': 'neutral'}

# %%
data
# Out:
# Kennzahl    Anteil Fußgänger an den Verkehrsmitteln in %  \
# Jahr
# 2010-01-01                                           NaN
# 2011-01-01                                           NaN
# 2012-01-01                                           NaN
# 2013-01-01                                          24.0
# 2014-01-01                                           NaN
# 2015-01-01                                           NaN
# 2016-01-01                                           NaN
# 2017-01-01                                           NaN
#
# Kennzahl    Anteil PKW an den Verkehrsmitteln in %  \
# Jahr
# 2010-01-01                                     NaN
# 2011-01-01                                     NaN
# 2012-01-01                                     NaN
# 2013-01-01                                    48.0
# 2014-01-01                                     NaN
# 2015-01-01                                     NaN
# 2016-01-01                                     NaN
# 2017-01-01                                     NaN
#
# Kennzahl    Anteil Radverkehr an den Verkehrsmitteln in %  \
# Jahr
# 2010-01-01                                            NaN
# 2011-01-01                                            NaN
# 2012-01-01                                            NaN
# 2013-01-01                                           20.0
# 2014-01-01                                            NaN
# 2015-01-01                                            NaN
# 2016-01-01                                            NaN
# 2017-01-01                                            NaN
#
# Kennzahl    Anteil zugelassener E-Fahrzeuge in %  \
# Jahr
# 2010-01-01                                   NaN
# 2011-01-01                                   NaN
# 2012-01-01                                   NaN
# 2013-01-01                                   NaN
# 2014-01-01                                   NaN
# 2015-01-01                                   NaN
# 2016-01-01                                   NaN
# 2017-01-01                                   6.0
#
# Kennzahl    Anteil zugelassener Plug-In Hybride am Gesamtbestand in %  \
# Jahr
# 2010-01-01                                                NaN
# 2011-01-01                                                NaN
# 2012-01-01                                                NaN
# 2013-01-01                                                NaN
# 2014-01-01                                                NaN
# 2015-01-01                                                NaN
# 2016-01-01                                                NaN
# 2017-01-01                                                3.0
#
# Kennzahl    Anteil ÖPNV an den Verkehrsmitteln in %  \
# Jahr
# 2010-01-01                                      NaN
# 2011-01-01                                      NaN
# 2012-01-01                                      NaN
# 2013-01-01                                      8.0
# 2014-01-01                                      NaN
# 2015-01-01                                      NaN
# 2016-01-01                                      NaN
# 2017-01-01                                      NaN
#
# Kennzahl    Anzahl Carsharing Fahrzeuge  Anzahl Carsharing Standorte  \
# Jahr
# 2010-01-01                          NaN                          NaN
# 2011-01-01                          NaN                          NaN
# 2012-01-01                         41.0                         36.0
# 2013-01-01                         49.0                         42.0
# 2014-01-01                         69.0                         44.0
# 2015-01-01                         86.0                         47.0
# 2016-01-01                         79.0                         50.0
# 2017-01-01                          NaN                          NaN
#
# Kennzahl    Anzahl Fahrradunfälle  mit leichtverletzten Personen  \
# Jahr
# 2010-01-01                                                NaN
# 2011-01-01                                                NaN
# 2012-01-01                                                NaN
# 2013-01-01                                              241.0
# 2014-01-01                                              253.0
# 2015-01-01                                              259.0
# 2016-01-01                                              274.0
# 2017-01-01                                                NaN
#
# Kennzahl    Anzahl Fahrradunfälle  mit schwerverletzten Personen  \
# Jahr
# 2010-01-01                                                NaN
# 2011-01-01                                                NaN
# 2012-01-01                                                NaN
# 2013-01-01                                               33.0
# 2014-01-01                                               50.0
# 2015-01-01                                               52.0
# 2016-01-01                                               49.0
# 2017-01-01                                                NaN
#
# Kennzahl    Anzahl der Fahrradunfälle in der Stadt Osnabrück  \
# Jahr
# 2010-01-01                                               NaN
# 2011-01-01                                               NaN
# 2012-01-01                                               NaN
# 2013-01-01                                             390.0
# 2014-01-01                                             431.0
# 2015-01-01                                             434.0
# 2016-01-01                                             443.0
# 2017-01-01                                               NaN
#
# Kennzahl    Anzahl der Personen, die eher unzufrieden und überhaupt nicht zufrieden mit dem öffentlichem Nahverkehr sind  \
# Jahr
# 2010-01-01                                                NaN
# 2011-01-01                                                NaN
# 2012-01-01                                                NaN
# 2013-01-01                                                NaN
# 2014-01-01                                                NaN
# 2015-01-01                                              111.0
# 2016-01-01                                                NaN
# 2017-01-01                                                NaN
#
# Kennzahl    Anzahl der Personen, die sehr und eher zufrieden mit dem öffentlichem Nahverkehr sind  \
# Jahr
# 2010-01-01                                                NaN
# 2011-01-01                                                NaN
# 2012-01-01                                                NaN
# 2013-01-01                                                NaN
# 2014-01-01                                                NaN
# 2015-01-01                                              370.0
# 2016-01-01                                                NaN
# 2017-01-01                                                NaN
#
# Kennzahl    Anzahl der Verkehrsunfälle in der Stadt Osnabrück  \
# Jahr
# 2010-01-01                                             5060.0
# 2011-01-01                                             5117.0
# 2012-01-01                                             5165.0
# 2013-01-01                                             5331.0
# 2014-01-01                                             5268.0
# 2015-01-01                                             5217.0
# 2016-01-01                                             4904.0
# 2017-01-01                                                NaN
#
# Kennzahl    Beförderte Personen (ÖPNV)  Carsharing Nutzer  \
# Jahr
# 2010-01-01                         NaN                NaN
# 2011-01-01                  35596801.0                NaN
# 2012-01-01                  35438793.0              737.0
# 2013-01-01                  35681996.0              960.0
# 2014-01-01                  35539657.0             1436.0
# 2015-01-01                  36075670.0             1860.0
# 2016-01-01                  36305605.0             2409.0
# 2017-01-01                         NaN                NaN
#
# Kennzahl    Durchschnitt PKW/Haushalt  PKW-Dichte (Pkw/1000EW)
# Jahr
# 2010-01-01                        NaN             4.720201e+16
# 2011-01-01                        NaN             4.751155e+15
# 2012-01-01                        NaN             4.792435e+16
# 2013-01-01                        NaN             4.842567e+15
# 2014-01-01                       77.0             4.907527e+15
# 2015-01-01                       78.0             4.789199e+15
# 2016-01-01                       79.0             4.825478e+16
# 2017-01-01                        8.0                      NaN

# %%
data_adjusted = data.copy()
for indicator, desired_direction in trend_dict.items():
    if desired_direction == 'negative':
        data_adjusted[indicator] *= -1
    elif desired_direction == 'neutral':
        del data_adjusted[indicator]
data_adjusted
# Out:
# Kennzahl    Anteil Fußgänger an den Verkehrsmitteln in %  \
# Jahr
# 2010-01-01                                           NaN
# 2011-01-01                                           NaN
# 2012-01-01                                           NaN
# 2013-01-01                                          24.0
# 2014-01-01                                           NaN
# 2015-01-01                                           NaN
# 2016-01-01                                           NaN
# 2017-01-01                                           NaN
#
# Kennzahl    Anteil PKW an den Verkehrsmitteln in %  \
# Jahr
# 2010-01-01                                     NaN
# 2011-01-01                                     NaN
# 2012-01-01                                     NaN
# 2013-01-01                                   -48.0
# 2014-01-01                                     NaN
# 2015-01-01                                     NaN
# 2016-01-01                                     NaN
# 2017-01-01                                     NaN
#
# Kennzahl    Anteil Radverkehr an den Verkehrsmitteln in %  \
# Jahr
# 2010-01-01                                            NaN
# 2011-01-01                                            NaN
# 2012-01-01                                            NaN
# 2013-01-01                                           20.0
# 2014-01-01                                            NaN
# 2015-01-01                                            NaN
# 2016-01-01                                            NaN
# 2017-01-01                                            NaN
#
# Kennzahl    Anteil zugelassener E-Fahrzeuge in %  \
# Jahr
# 2010-01-01                                   NaN
# 2011-01-01                                   NaN
# 2012-01-01                                   NaN
# 2013-01-01                                   NaN
# 2014-01-01                                   NaN
# 2015-01-01                                   NaN
# 2016-01-01                                   NaN
# 2017-01-01                                   6.0
#
# Kennzahl    Anteil zugelassener Plug-In Hybride am Gesamtbestand in %  \
# Jahr
# 2010-01-01                                                NaN
# 2011-01-01                                                NaN
# 2012-01-01                                                NaN
# 2013-01-01                                                NaN
# 2014-01-01                                                NaN
# 2015-01-01                                                NaN
# 2016-01-01                                                NaN
# 2017-01-01                                                3.0
#
# Kennzahl    Anteil ÖPNV an den Verkehrsmitteln in %  \
# Jahr
# 2010-01-01                                      NaN
# 2011-01-01                                      NaN
# 2012-01-01                                      NaN
# 2013-01-01                                      8.0
# 2014-01-01                                      NaN
# 2015-01-01                                      NaN
# 2016-01-01                                      NaN
# 2017-01-01                                      NaN
#
# Kennzahl    Anzahl Carsharing Fahrzeuge  Anzahl Carsharing Standorte  \
# Jahr
# 2010-01-01                          NaN                          NaN
# 2011-01-01                          NaN                          NaN
# 2012-01-01                         41.0                         36.0
# 2013-01-01                         49.0                         42.0
# 2014-01-01                         69.0                         44.0
# 2015-01-01                         86.0                         47.0
# 2016-01-01                         79.0                         50.0
# 2017-01-01                          NaN                          NaN
#
# Kennzahl    Anzahl Fahrradunfälle  mit leichtverletzten Personen  \
# Jahr
# 2010-01-01                                                NaN
# 2011-01-01                                                NaN
# 2012-01-01                                                NaN
# 2013-01-01                                             -241.0
# 2014-01-01                                             -253.0
# 2015-01-01                                             -259.0
# 2016-01-01                                             -274.0
# 2017-01-01                                                NaN
#
# Kennzahl    Anzahl Fahrradunfälle  mit schwerverletzten Personen  \
# Jahr
# 2010-01-01                                                NaN
# 2011-01-01                                                NaN
# 2012-01-01                                                NaN
# 2013-01-01                                              -33.0
# 2014-01-01                                              -50.0
# 2015-01-01                                              -52.0
# 2016-01-01                                              -49.0
# 2017-01-01                                                NaN
#
# Kennzahl    Anzahl der Fahrradunfälle in der Stadt Osnabrück  \
# Jahr
# 2010-01-01                                               NaN
# 2011-01-01                                               NaN
# 2012-01-01                                               NaN
# 2013-01-01                                            -390.0
# 2014-01-01                                            -431.0
# 2015-01-01                                            -434.0
# 2016-01-01                                            -443.0
# 2017-01-01                                               NaN
#
# Kennzahl    Anzahl der Personen, die eher unzufrieden und überhaupt nicht zufrieden mit dem öffentlichem Nahverkehr sind  \
# Jahr
# 2010-01-01                                                NaN
# 2011-01-01                                                NaN
# 2012-01-01                                                NaN
# 2013-01-01                                                NaN
# 2014-01-01                                                NaN
# 2015-01-01                                             -111.0
# 2016-01-01                                                NaN
# 2017-01-01                                                NaN
#
# Kennzahl    Anzahl der Personen, die sehr und eher zufrieden mit dem öffentlichem Nahverkehr sind  \
# Jahr
# 2010-01-01                                                NaN
# 2011-01-01                                                NaN
# 2012-01-01                                                NaN
# 2013-01-01                                                NaN
# 2014-01-01                                                NaN
# 2015-01-01                                              370.0
# 2016-01-01                                                NaN
# 2017-01-01                                                NaN
#
# Kennzahl    Anzahl der Verkehrsunfälle in der Stadt Osnabrück  \
# Jahr
# 2010-01-01                                            -5060.0
# 2011-01-01                                            -5117.0
# 2012-01-01                                            -5165.0
# 2013-01-01                                            -5331.0
# 2014-01-01                                            -5268.0
# 2015-01-01                                            -5217.0
# 2016-01-01                                            -4904.0
# 2017-01-01                                                NaN
#
# Kennzahl    Beförderte Personen (ÖPNV)  Carsharing Nutzer
# Jahr
# 2010-01-01                         NaN                NaN
# 2011-01-01                  35596801.0                NaN
# 2012-01-01                  35438793.0              737.0
# 2013-01-01                  35681996.0              960.0
# 2014-01-01                  35539657.0             1436.0
# 2015-01-01                  36075670.0             1860.0
# 2016-01-01                  36305605.0             2409.0
# 2017-01-01                         NaN                NaN

# %%
diff = data_adjusted.diff()
diff
# Out:
# Kennzahl    Anteil Fußgänger an den Verkehrsmitteln in %  \
# Jahr
# 2010-01-01                                           NaN
# 2011-01-01                                           NaN
# 2012-01-01                                           NaN
# 2013-01-01                                           NaN
# 2014-01-01                                           NaN
# 2015-01-01                                           NaN
# 2016-01-01                                           NaN
# 2017-01-01                                           NaN
#
# Kennzahl    Anteil PKW an den Verkehrsmitteln in %  \
# Jahr
# 2010-01-01                                     NaN
# 2011-01-01                                     NaN
# 2012-01-01                                     NaN
# 2013-01-01                                     NaN
# 2014-01-01                                     NaN
# 2015-01-01                                     NaN
# 2016-01-01                                     NaN
# 2017-01-01                                     NaN
#
# Kennzahl    Anteil Radverkehr an den Verkehrsmitteln in %  \
# Jahr
# 2010-01-01                                            NaN
# 2011-01-01                                            NaN
# 2012-01-01                                            NaN
# 2013-01-01                                            NaN
# 2014-01-01                                            NaN
# 2015-01-01                                            NaN
# 2016-01-01                                            NaN
# 2017-01-01                                            NaN
#
# Kennzahl    Anteil zugelassener E-Fahrzeuge in %  \
# Jahr
# 2010-01-01                                   NaN
# 2011-01-01                                   NaN
# 2012-01-01                                   NaN
# 2013-01-01                                   NaN
# 2014-01-01                                   NaN
# 2015-01-01                                   NaN
# 2016-01-01                                   NaN
# 2017-01-01                                   NaN
#
# Kennzahl    Anteil zugelassener Plug-In Hybride am Gesamtbestand in %  \
# Jahr
# 2010-01-01                                                NaN
# 2011-01-01                                                NaN
# 2012-01-01                                                NaN
# 2013-01-01                                                NaN
# 2014-01-01                                                NaN
# 2015-01-01                                                NaN
# 2016-01-01                                                NaN
# 2017-01-01                                                NaN
#
# Kennzahl    Anteil ÖPNV an den Verkehrsmitteln in %  \
# Jahr
# 2010-01-01                                      NaN
# 2011-01-01                                      NaN
# 2012-01-01                                      NaN
# 2013-01-01                                      NaN
# 2014-01-01                                      NaN
# 2015-01-01                                      NaN
# 2016-01-01                                      NaN
# 2017-01-01                                      NaN
#
# Kennzahl    Anzahl Carsharing Fahrzeuge  Anzahl Carsharing Standorte  \
# Jahr
# 2010-01-01                          NaN                          NaN
# 2011-01-01                          NaN                          NaN
# 2012-01-01                          NaN                          NaN
# 2013-01-01                          8.0                          6.0
# 2014-01-01                         20.0                          2.0
# 2015-01-01                         17.0                          3.0
# 2016-01-01                         -7.0                          3.0
# 2017-01-01                          NaN                          NaN
#
# Kennzahl    Anzahl Fahrradunfälle  mit leichtverletzten Personen  \
# Jahr
# 2010-01-01                                                NaN
# 2011-01-01                                                NaN
# 2012-01-01                                                NaN
# 2013-01-01                                                NaN
# 2014-01-01                                              -12.0
# 2015-01-01                                               -6.0
# 2016-01-01                                              -15.0
# 2017-01-01                                                NaN
#
# Kennzahl    Anzahl Fahrradunfälle  mit schwerverletzten Personen  \
# Jahr
# 2010-01-01                                                NaN
# 2011-01-01                                                NaN
# 2012-01-01                                                NaN
# 2013-01-01                                                NaN
# 2014-01-01                                              -17.0
# 2015-01-01                                               -2.0
# 2016-01-01                                                3.0
# 2017-01-01                                                NaN
#
# Kennzahl    Anzahl der Fahrradunfälle in der Stadt Osnabrück  \
# Jahr
# 2010-01-01                                               NaN
# 2011-01-01                                               NaN
# 2012-01-01                                               NaN
# 2013-01-01                                               NaN
# 2014-01-01                                             -41.0
# 2015-01-01                                              -3.0
# 2016-01-01                                              -9.0
# 2017-01-01                                               NaN
#
# Kennzahl    Anzahl der Personen, die eher unzufrieden und überhaupt nicht zufrieden mit dem öffentlichem Nahverkehr sind  \
# Jahr
# 2010-01-01                                                NaN
# 2011-01-01                                                NaN
# 2012-01-01                                                NaN
# 2013-01-01                                                NaN
# 2014-01-01                                                NaN
# 2015-01-01                                                NaN
# 2016-01-01                                                NaN
# 2017-01-01                                                NaN
#
# Kennzahl    Anzahl der Personen, die sehr und eher zufrieden mit dem öffentlichem Nahverkehr sind  \
# Jahr
# 2010-01-01                                                NaN
# 2011-01-01                                                NaN
# 2012-01-01                                                NaN
# 2013-01-01                                                NaN
# 2014-01-01                                                NaN
# 2015-01-01                                                NaN
# 2016-01-01                                                NaN
# 2017-01-01                                                NaN
#
# Kennzahl    Anzahl der Verkehrsunfälle in der Stadt Osnabrück  \
# Jahr
# 2010-01-01                                                NaN
# 2011-01-01                                              -57.0
# 2012-01-01                                              -48.0
# 2013-01-01                                             -166.0
# 2014-01-01                                               63.0
# 2015-01-01                                               51.0
# 2016-01-01                                              313.0
# 2017-01-01                                                NaN
#
# Kennzahl    Beförderte Personen (ÖPNV)  Carsharing Nutzer
# Jahr
# 2010-01-01                         NaN                NaN
# 2011-01-01                         NaN                NaN
# 2012-01-01                   -158008.0                NaN
# 2013-01-01                    243203.0              223.0
# 2014-01-01                   -142339.0              476.0
# 2015-01-01                    536013.0              424.0
# 2016-01-01                    229935.0              549.0
# 2017-01-01                         NaN                NaN

# %%
trend = diff > 0
trend[diff.isna()] = np.nan
trend[trend == 0] = -1
trend
# Out:
# Kennzahl    Anteil Fußgänger an den Verkehrsmitteln in %  \
# Jahr
# 2010-01-01                                           NaN
# 2011-01-01                                           NaN
# 2012-01-01                                           NaN
# 2013-01-01                                           NaN
# 2014-01-01                                           NaN
# 2015-01-01                                           NaN
# 2016-01-01                                           NaN
# 2017-01-01                                           NaN
#
# Kennzahl    Anteil PKW an den Verkehrsmitteln in %  \
# Jahr
# 2010-01-01                                     NaN
# 2011-01-01                                     NaN
# 2012-01-01                                     NaN
# 2013-01-01                                     NaN
# 2014-01-01                                     NaN
# 2015-01-01                                     NaN
# 2016-01-01                                     NaN
# 2017-01-01                                     NaN
#
# Kennzahl    Anteil Radverkehr an den Verkehrsmitteln in %  \
# Jahr
# 2010-01-01                                            NaN
# 2011-01-01                                            NaN
# 2012-01-01                                            NaN
# 2013-01-01                                            NaN
# 2014-01-01                                            NaN
# 2015-01-01                                            NaN
# 2016-01-01                                            NaN
# 2017-01-01                                            NaN
#
# Kennzahl    Anteil zugelassener E-Fahrzeuge in %  \
# Jahr
# 2010-01-01                                   NaN
# 2011-01-01                                   NaN
# 2012-01-01                                   NaN
# 2013-01-01                                   NaN
# 2014-01-01                                   NaN
# 2015-01-01                                   NaN
# 2016-01-01                                   NaN
# 2017-01-01                                   NaN
#
# Kennzahl    Anteil zugelassener Plug-In Hybride am Gesamtbestand in %  \
# Jahr
# 2010-01-01                                                NaN
# 2011-01-01                                                NaN
# 2012-01-01                                                NaN
# 2013-01-01                                                NaN
# 2014-01-01                                                NaN
# 2015-01-01                                                NaN
# 2016-01-01                                                NaN
# 2017-01-01                                                NaN
#
# Kennzahl    Anteil ÖPNV an den Verkehrsmitteln in %  \
# Jahr
# 2010-01-01                                      NaN
# 2011-01-01                                      NaN
# 2012-01-01                                      NaN
# 2013-01-01                                      NaN
# 2014-01-01                                      NaN
# 2015-01-01                                      NaN
# 2016-01-01                                      NaN
# 2017-01-01                                      NaN
#
# Kennzahl    Anzahl Carsharing Fahrzeuge  Anzahl Carsharing Standorte  \
# Jahr
# 2010-01-01                          NaN                          NaN
# 2011-01-01                          NaN                          NaN
# 2012-01-01                          NaN                          NaN
# 2013-01-01                          1.0                          1.0
# 2014-01-01                          1.0                          1.0
# 2015-01-01                          1.0                          1.0
# 2016-01-01                         -1.0                          1.0
# 2017-01-01                          NaN                          NaN
#
# Kennzahl    Anzahl Fahrradunfälle  mit leichtverletzten Personen  \
# Jahr
# 2010-01-01                                                NaN
# 2011-01-01                                                NaN
# 2012-01-01                                                NaN
# 2013-01-01                                                NaN
# 2014-01-01                                               -1.0
# 2015-01-01                                               -1.0
# 2016-01-01                                               -1.0
# 2017-01-01                                                NaN
#
# Kennzahl    Anzahl Fahrradunfälle  mit schwerverletzten Personen  \
# Jahr
# 2010-01-01                                                NaN
# 2011-01-01                                                NaN
# 2012-01-01                                                NaN
# 2013-01-01                                                NaN
# 2014-01-01                                               -1.0
# 2015-01-01                                               -1.0
# 2016-01-01                                                1.0
# 2017-01-01                                                NaN
#
# Kennzahl    Anzahl der Fahrradunfälle in der Stadt Osnabrück  \
# Jahr
# 2010-01-01                                               NaN
# 2011-01-01                                               NaN
# 2012-01-01                                               NaN
# 2013-01-01                                               NaN
# 2014-01-01                                              -1.0
# 2015-01-01                                              -1.0
# 2016-01-01                                              -1.0
# 2017-01-01                                               NaN
#
# Kennzahl    Anzahl der Personen, die eher unzufrieden und überhaupt nicht zufrieden mit dem öffentlichem Nahverkehr sind  \
# Jahr
# 2010-01-01                                                NaN
# 2011-01-01                                                NaN
# 2012-01-01                                                NaN
# 2013-01-01                                                NaN
# 2014-01-01                                                NaN
# 2015-01-01                                                NaN
# 2016-01-01                                                NaN
# 2017-01-01                                                NaN
#
# Kennzahl    Anzahl der Personen, die sehr und eher zufrieden mit dem öffentlichem Nahverkehr sind  \
# Jahr
# 2010-01-01                                                NaN
# 2011-01-01                                                NaN
# 2012-01-01                                                NaN
# 2013-01-01                                                NaN
# 2014-01-01                                                NaN
# 2015-01-01                                                NaN
# 2016-01-01                                                NaN
# 2017-01-01                                                NaN
#
# Kennzahl    Anzahl der Verkehrsunfälle in der Stadt Osnabrück  \
# Jahr
# 2010-01-01                                                NaN
# 2011-01-01                                               -1.0
# 2012-01-01                                               -1.0
# 2013-01-01                                               -1.0
# 2014-01-01                                                1.0
# 2015-01-01                                                1.0
# 2016-01-01                                                1.0
# 2017-01-01                                                NaN
#
# Kennzahl    Beförderte Personen (ÖPNV)  Carsharing Nutzer
# Jahr
# 2010-01-01                         NaN                NaN
# 2011-01-01                         NaN                NaN
# 2012-01-01                        -1.0                NaN
# 2013-01-01                         1.0                1.0
# 2014-01-01                        -1.0                1.0
# 2015-01-01                         1.0                1.0
# 2016-01-01                         1.0                1.0
# 2017-01-01                         NaN                NaN

# %%
trend_avg = trend.mean(axis='columns')
trend_avg
# Out:
# Jahr
# 2010-01-01     NaN
# 2011-01-01   -1.00
# 2012-01-01   -1.00
# 2013-01-01    0.60
# 2014-01-01    0.00
# 2015-01-01    0.25
# 2016-01-01    0.25
# 2017-01-01     NaN
# dtype: float64

# %%
n_values_per_year = (~trend.isna()).sum(axis='columns') / len(trend.columns)
n_values_per_year
# Out:
# Jahr
# 2010-01-01    0.0000
# 2011-01-01    0.0625
# 2012-01-01    0.1250
# 2013-01-01    0.3125
# 2014-01-01    0.5000
# 2015-01-01    0.5000
# 2016-01-01    0.5000
# 2017-01-01    0.0000
# dtype: float64

# %%
weighted_trend_avg = pd.DataFrame({
    'year': trend_avg.index, 
    'trend': trend_avg,
    'quota': n_values_per_year
    
})

weighted_trend_avg
# Out:
#                  year  trend   quota
# Jahr
# 2010-01-01 2010-01-01    NaN  0.0000
# 2011-01-01 2011-01-01  -1.00  0.0625
# 2012-01-01 2012-01-01  -1.00  0.1250
# 2013-01-01 2013-01-01   0.60  0.3125
# 2014-01-01 2014-01-01   0.00  0.5000
# 2015-01-01 2015-01-01   0.25  0.5000
# 2016-01-01 2016-01-01   0.25  0.5000
# 2017-01-01 2017-01-01    NaN  0.0000

# %%
(ggplot(weighted_trend_avg, aes(x='year', y='trend', size='quota'))
 + geom_point()
 + geom_line(size=1)
 + geom_hline(aes(yintercept=0), linetype='--')
 + ylim(-1, 1)
)
# Out:
# /home/jarno/.miniconda/envs/scientific/lib/python3.6/site-packages/plotnine/layer.py:452: UserWarning: geom_point : Removed 2 rows containing missing values.
#   self.data = self.geom.handle_na(self.data)
# /home/jarno/.miniconda/envs/scientific/lib/python3.6/site-packages/plotnine/geoms/geom_path.py:76: UserWarning: geom_path: Removed 2 rows containing missing values.
#   warn(msg.format(n1-n2))
# <ggplot: (8767805678600)>

# %%
data_full = pd.concat((weighted_trend_avg, data), axis=1)
data_full
# Out:
#                  year  trend   quota  \
# Jahr
# 2010-01-01 2010-01-01    NaN  0.0000
# 2011-01-01 2011-01-01  -1.00  0.0625
# 2012-01-01 2012-01-01  -1.00  0.1250
# 2013-01-01 2013-01-01   0.60  0.3125
# 2014-01-01 2014-01-01   0.00  0.5000
# 2015-01-01 2015-01-01   0.25  0.5000
# 2016-01-01 2016-01-01   0.25  0.5000
# 2017-01-01 2017-01-01    NaN  0.0000
#
#             Anteil Fußgänger an den Verkehrsmitteln in %  \
# Jahr
# 2010-01-01                                           NaN
# 2011-01-01                                           NaN
# 2012-01-01                                           NaN
# 2013-01-01                                          24.0
# 2014-01-01                                           NaN
# 2015-01-01                                           NaN
# 2016-01-01                                           NaN
# 2017-01-01                                           NaN
#
#             Anteil PKW an den Verkehrsmitteln in %  \
# Jahr
# 2010-01-01                                     NaN
# 2011-01-01                                     NaN
# 2012-01-01                                     NaN
# 2013-01-01                                    48.0
# 2014-01-01                                     NaN
# 2015-01-01                                     NaN
# 2016-01-01                                     NaN
# 2017-01-01                                     NaN
#
#             Anteil Radverkehr an den Verkehrsmitteln in %  \
# Jahr
# 2010-01-01                                            NaN
# 2011-01-01                                            NaN
# 2012-01-01                                            NaN
# 2013-01-01                                           20.0
# 2014-01-01                                            NaN
# 2015-01-01                                            NaN
# 2016-01-01                                            NaN
# 2017-01-01                                            NaN
#
#             Anteil zugelassener E-Fahrzeuge in %  \
# Jahr
# 2010-01-01                                   NaN
# 2011-01-01                                   NaN
# 2012-01-01                                   NaN
# 2013-01-01                                   NaN
# 2014-01-01                                   NaN
# 2015-01-01                                   NaN
# 2016-01-01                                   NaN
# 2017-01-01                                   6.0
#
#             Anteil zugelassener Plug-In Hybride am Gesamtbestand in %  \
# Jahr
# 2010-01-01                                                NaN
# 2011-01-01                                                NaN
# 2012-01-01                                                NaN
# 2013-01-01                                                NaN
# 2014-01-01                                                NaN
# 2015-01-01                                                NaN
# 2016-01-01                                                NaN
# 2017-01-01                                                3.0
#
#             Anteil ÖPNV an den Verkehrsmitteln in %  \
# Jahr
# 2010-01-01                                      NaN
# 2011-01-01                                      NaN
# 2012-01-01                                      NaN
# 2013-01-01                                      8.0
# 2014-01-01                                      NaN
# 2015-01-01                                      NaN
# 2016-01-01                                      NaN
# 2017-01-01                                      NaN
#
#             Anzahl Carsharing Fahrzeuge           ...             \
# Jahr                                              ...
# 2010-01-01                          NaN           ...
# 2011-01-01                          NaN           ...
# 2012-01-01                         41.0           ...
# 2013-01-01                         49.0           ...
# 2014-01-01                         69.0           ...
# 2015-01-01                         86.0           ...
# 2016-01-01                         79.0           ...
# 2017-01-01                          NaN           ...
#
#             Anzahl Fahrradunfälle  mit leichtverletzten Personen  \
# Jahr
# 2010-01-01                                                NaN
# 2011-01-01                                                NaN
# 2012-01-01                                                NaN
# 2013-01-01                                              241.0
# 2014-01-01                                              253.0
# 2015-01-01                                              259.0
# 2016-01-01                                              274.0
# 2017-01-01                                                NaN
#
#             Anzahl Fahrradunfälle  mit schwerverletzten Personen  \
# Jahr
# 2010-01-01                                                NaN
# 2011-01-01                                                NaN
# 2012-01-01                                                NaN
# 2013-01-01                                               33.0
# 2014-01-01                                               50.0
# 2015-01-01                                               52.0
# 2016-01-01                                               49.0
# 2017-01-01                                                NaN
#
#             Anzahl der Fahrradunfälle in der Stadt Osnabrück  \
# Jahr
# 2010-01-01                                               NaN
# 2011-01-01                                               NaN
# 2012-01-01                                               NaN
# 2013-01-01                                             390.0
# 2014-01-01                                             431.0
# 2015-01-01                                             434.0
# 2016-01-01                                             443.0
# 2017-01-01                                               NaN
#
#             Anzahl der Personen, die eher unzufrieden und überhaupt nicht zufrieden mit dem öffentlichem Nahverkehr sind  \
# Jahr
# 2010-01-01                                                NaN
# 2011-01-01                                                NaN
# 2012-01-01                                                NaN
# 2013-01-01                                                NaN
# 2014-01-01                                                NaN
# 2015-01-01                                              111.0
# 2016-01-01                                                NaN
# 2017-01-01                                                NaN
#
#             Anzahl der Personen, die sehr und eher zufrieden mit dem öffentlichem Nahverkehr sind  \
# Jahr
# 2010-01-01                                                NaN
# 2011-01-01                                                NaN
# 2012-01-01                                                NaN
# 2013-01-01                                                NaN
# 2014-01-01                                                NaN
# 2015-01-01                                              370.0
# 2016-01-01                                                NaN
# 2017-01-01                                                NaN
#
#             Anzahl der Verkehrsunfälle in der Stadt Osnabrück  \
# Jahr
# 2010-01-01                                             5060.0
# 2011-01-01                                             5117.0
# 2012-01-01                                             5165.0
# 2013-01-01                                             5331.0
# 2014-01-01                                             5268.0
# 2015-01-01                                             5217.0
# 2016-01-01                                             4904.0
# 2017-01-01                                                NaN
#
#             Beförderte Personen (ÖPNV)  Carsharing Nutzer  \
# Jahr
# 2010-01-01                         NaN                NaN
# 2011-01-01                  35596801.0                NaN
# 2012-01-01                  35438793.0              737.0
# 2013-01-01                  35681996.0              960.0
# 2014-01-01                  35539657.0             1436.0
# 2015-01-01                  36075670.0             1860.0
# 2016-01-01                  36305605.0             2409.0
# 2017-01-01                         NaN                NaN
#
#             Durchschnitt PKW/Haushalt  PKW-Dichte (Pkw/1000EW)
# Jahr
# 2010-01-01                        NaN             4.720201e+16
# 2011-01-01                        NaN             4.751155e+15
# 2012-01-01                        NaN             4.792435e+16
# 2013-01-01                        NaN             4.842567e+15
# 2014-01-01                       77.0             4.907527e+15
# 2015-01-01                       78.0             4.789199e+15
# 2016-01-01                       79.0             4.825478e+16
# 2017-01-01                        8.0                      NaN
#
# [8 rows x 21 columns]

# %%
base_chart = alt.Chart(data_full).encode(
    x='year',
    y=alt.Y('trend', scale=alt.Scale(domain=(-1.1, 1.1))),
    tooltip=[col for col in data_full.columns if col not in ['trend', 'quota', 'year']]
)

base_chart.mark_circle().encode(size='quota') + base_chart.mark_line()
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html
