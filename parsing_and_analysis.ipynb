# %%
import pandas as pd
import numpy as np
import seaborn
import altair as alt
from plotnine import *

# %%
df = pd.read_csv('Excel_Export_Ziel3.csv')
df.head()
# Out:
#              Stadtbereich Nachhaltige Mobilitätskonzepte Unnamed: 2  \
# 0                     NaN              Carsharing Nutzer        NaN
# 1                     NaN                           2012       2013
# 2  Stadt Osnabrück gesamt                            737        960
# 3              Innenstadt                              -          -
# 4               Weststadt                              -          -
#
#   Unnamed: 3 Unnamed: 4 Unnamed: 5                   Unnamed: 6 Unnamed: 7  \
# 0        NaN        NaN        NaN  Anzahl Carsharing Fahrzeuge        NaN
# 1       2014       2015       2016                         2012       2013
# 2       1436       1860       2409                           41         49
# 3          -          -          -                            -          -
# 4          -          -          -                            -          -
#
#   Unnamed: 8 Unnamed: 9                   ...                    Unnamed: 50  \
# 0        NaN        NaN                   ...                            NaN
# 1       2014       2015                   ...                           2012
# 2         69         86                   ...                            479
# 3          -          -                   ...                              -
# 4          -          -                   ...                              -
#
#   Unnamed: 51 Unnamed: 52 Unnamed: 53 Unnamed: 54                Unnamed: 55  \
# 0         NaN         NaN         NaN         NaN  Durchschnitt PKW/Haushalt
# 1        2013        2014        2015        2016                       2014
# 2         484         491         479         483                       0.77
# 3           -           -           -           -                       0.37
# 4           -           -           -           -                       0.72
#
#   Unnamed: 56 Unnamed: 57 Unnamed: 58                              Unnamed: 59
# 0         NaN         NaN         NaN  Anteil ÖPNV an den Verkehrsmitteln in %
# 1     2015.00     2016.00     2017.00                                     2013
# 2        0.78        0.79        0.80                                        8
# 3        0.38        0.38        0.40                                        -
# 4        0.71        0.73        0.72                                        -
#
# [5 rows x 60 columns]

# %%
df.iloc[0] = df.iloc[0].ffill()
df.head()
# Out:
#              Stadtbereich Nachhaltige Mobilitätskonzepte         Unnamed: 2  \
# 0                     NaN              Carsharing Nutzer  Carsharing Nutzer
# 1                     NaN                           2012               2013
# 2  Stadt Osnabrück gesamt                            737                960
# 3              Innenstadt                              -                  -
# 4               Weststadt                              -                  -
#
#           Unnamed: 3         Unnamed: 4         Unnamed: 5  \
# 0  Carsharing Nutzer  Carsharing Nutzer  Carsharing Nutzer
# 1               2014               2015               2016
# 2               1436               1860               2409
# 3                  -                  -                  -
# 4                  -                  -                  -
#
#                     Unnamed: 6                   Unnamed: 7  \
# 0  Anzahl Carsharing Fahrzeuge  Anzahl Carsharing Fahrzeuge
# 1                         2012                         2013
# 2                           41                           49
# 3                            -                            -
# 4                            -                            -
#
#                     Unnamed: 8                   Unnamed: 9  \
# 0  Anzahl Carsharing Fahrzeuge  Anzahl Carsharing Fahrzeuge
# 1                         2014                         2015
# 2                           69                           86
# 3                            -                            -
# 4                            -                            -
#
#                     ...                                 Unnamed: 50  \
# 0                   ...                     PKW-Dichte (Pkw/1000EW)
# 1                   ...                                        2012
# 2                   ...                                         479
# 3                   ...                                           -
# 4                   ...                                           -
#
#                Unnamed: 51              Unnamed: 52              Unnamed: 53  \
# 0  PKW-Dichte (Pkw/1000EW)  PKW-Dichte (Pkw/1000EW)  PKW-Dichte (Pkw/1000EW)
# 1                     2013                     2014                     2015
# 2                      484                      491                      479
# 3                        -                        -                        -
# 4                        -                        -                        -
#
#                Unnamed: 54                Unnamed: 55  \
# 0  PKW-Dichte (Pkw/1000EW)  Durchschnitt PKW/Haushalt
# 1                     2016                       2014
# 2                      483                       0.77
# 3                        -                       0.37
# 4                        -                       0.72
#
#                  Unnamed: 56                Unnamed: 57  \
# 0  Durchschnitt PKW/Haushalt  Durchschnitt PKW/Haushalt
# 1                       2015                       2016
# 2                       0.78                       0.79
# 3                       0.38                       0.38
# 4                       0.71                       0.73
#
#                  Unnamed: 58                              Unnamed: 59
# 0  Durchschnitt PKW/Haushalt  Anteil ÖPNV an den Verkehrsmitteln in %
# 1                       2017                                     2013
# 2                        0.8                                        8
# 3                        0.4                                        -
# 4                       0.72                                        -
#
# [5 rows x 60 columns]

# %%
df = df.iloc[:3, 1:]
df
# Out:
#   Nachhaltige Mobilitätskonzepte         Unnamed: 2         Unnamed: 3  \
# 0              Carsharing Nutzer  Carsharing Nutzer  Carsharing Nutzer
# 1                           2012               2013               2014
# 2                            737                960               1436
#
#           Unnamed: 4         Unnamed: 5                   Unnamed: 6  \
# 0  Carsharing Nutzer  Carsharing Nutzer  Anzahl Carsharing Fahrzeuge
# 1               2015               2016                         2012
# 2               1860               2409                           41
#
#                     Unnamed: 7                   Unnamed: 8  \
# 0  Anzahl Carsharing Fahrzeuge  Anzahl Carsharing Fahrzeuge
# 1                         2013                         2014
# 2                           49                           69
#
#                     Unnamed: 9                  Unnamed: 10  \
# 0  Anzahl Carsharing Fahrzeuge  Anzahl Carsharing Fahrzeuge
# 1                         2015                         2016
# 2                           86                           79
#
#                     ...                                 Unnamed: 50  \
# 0                   ...                     PKW-Dichte (Pkw/1000EW)
# 1                   ...                                        2012
# 2                   ...                                         479
#
#                Unnamed: 51              Unnamed: 52              Unnamed: 53  \
# 0  PKW-Dichte (Pkw/1000EW)  PKW-Dichte (Pkw/1000EW)  PKW-Dichte (Pkw/1000EW)
# 1                     2013                     2014                     2015
# 2                      484                      491                      479
#
#                Unnamed: 54                Unnamed: 55  \
# 0  PKW-Dichte (Pkw/1000EW)  Durchschnitt PKW/Haushalt
# 1                     2016                       2014
# 2                      483                       0.77
#
#                  Unnamed: 56                Unnamed: 57  \
# 0  Durchschnitt PKW/Haushalt  Durchschnitt PKW/Haushalt
# 1                       2015                       2016
# 2                       0.78                       0.79
#
#                  Unnamed: 58                              Unnamed: 59
# 0  Durchschnitt PKW/Haushalt  Anteil ÖPNV an den Verkehrsmitteln in %
# 1                       2017                                     2013
# 2                        0.8                                        8
#
# [3 rows x 59 columns]

# %%
detailgoal = pd.Series(df.columns)
detailgoal[detailgoal.str.startswith('Unnamed')] = None
detailgoal = detailgoal.ffill()
detailgoal.tail()
# Out:
# 54    Weiteres
# 55    Weiteres
# 56    Weiteres
# 57    Weiteres
# 58    Weiteres
# dtype: object

# %%
data = pd.DataFrame({
    'Detailziel': detailgoal,
    'Indikator': df.iloc[0].reset_index(drop=True),
    'Jahr': df.iloc[1].reset_index(drop=True),
    'Wert': df.iloc[2].reset_index(drop=True),
})
data
# Out:
#                                  Detailziel  \
# 0            Nachhaltige Mobilitätskonzepte
# 1            Nachhaltige Mobilitätskonzepte
# 2            Nachhaltige Mobilitätskonzepte
# 3            Nachhaltige Mobilitätskonzepte
# 4            Nachhaltige Mobilitätskonzepte
# 5            Nachhaltige Mobilitätskonzepte
# 6            Nachhaltige Mobilitätskonzepte
# 7            Nachhaltige Mobilitätskonzepte
# 8            Nachhaltige Mobilitätskonzepte
# 9            Nachhaltige Mobilitätskonzepte
# 10           Nachhaltige Mobilitätskonzepte
# 11           Nachhaltige Mobilitätskonzepte
# 12           Nachhaltige Mobilitätskonzepte
# 13           Nachhaltige Mobilitätskonzepte
# 14           Nachhaltige Mobilitätskonzepte
# 15                      E-Mobilität fördern
# 16                      E-Mobilität fördern
# 17                       Radverkehr stärken
# 18                       Radverkehr stärken
# 19                       Radverkehr stärken
# 20                       Radverkehr stärken
# 21                       Radverkehr stärken
# 22                       Radverkehr stärken
# 23                       Radverkehr stärken
# 24                       Radverkehr stärken
# 25                       Radverkehr stärken
# 26  Öffentlichen Personennahverkehr fördern
# 27  Öffentlichen Personennahverkehr fördern
# 28  Öffentlichen Personennahverkehr fördern
# 29  Öffentlichen Personennahverkehr fördern
# 30  Öffentlichen Personennahverkehr fördern
# 31  Öffentlichen Personennahverkehr fördern
# 32  Öffentlichen Personennahverkehr fördern
# 33  Öffentlichen Personennahverkehr fördern
# 34                                 Weiteres
# 35                                 Weiteres
# 36                                 Weiteres
# 37                                 Weiteres
# 38                                 Weiteres
# 39                                 Weiteres
# 40                                 Weiteres
# 41                                 Weiteres
# 42                                 Weiteres
# 43                                 Weiteres
# 44                                 Weiteres
# 45                                 Weiteres
# 46                                 Weiteres
# 47                                 Weiteres
# 48                                 Weiteres
# 49                                 Weiteres
# 50                                 Weiteres
# 51                                 Weiteres
# 52                                 Weiteres
# 53                                 Weiteres
# 54                                 Weiteres
# 55                                 Weiteres
# 56                                 Weiteres
# 57                                 Weiteres
# 58                                 Weiteres
#
#                                             Indikator  Jahr        Wert
# 0                                   Carsharing Nutzer  2012         737
# 1                                   Carsharing Nutzer  2013         960
# 2                                   Carsharing Nutzer  2014        1436
# 3                                   Carsharing Nutzer  2015        1860
# 4                                   Carsharing Nutzer  2016        2409
# 5                         Anzahl Carsharing Fahrzeuge  2012          41
# 6                         Anzahl Carsharing Fahrzeuge  2013          49
# 7                         Anzahl Carsharing Fahrzeuge  2014          69
# 8                         Anzahl Carsharing Fahrzeuge  2015          86
# 9                         Anzahl Carsharing Fahrzeuge  2016          79
# 10                        Anzahl Carsharing Standorte  2012          36
# 11                        Anzahl Carsharing Standorte  2013          42
# 12                        Anzahl Carsharing Standorte  2014          44
# 13                        Anzahl Carsharing Standorte  2015          47
# 14                        Anzahl Carsharing Standorte  2016          50
# 15               Anteil zugelassener E-Fahrzeuge in %  2017        0.06
# 16  Anteil zugelassener Plug-In Hybride am Gesamtb...  2017        0.03
# 17      Anteil Radverkehr an den Verkehrsmitteln in %  2013          20
# 18  Anzahl Fahrradunfälle  mit leichtverletzten Pe...  2013         241
# 19  Anzahl Fahrradunfälle  mit leichtverletzten Pe...  2014         253
# 20  Anzahl Fahrradunfälle  mit leichtverletzten Pe...  2015         259
# 21  Anzahl Fahrradunfälle  mit leichtverletzten Pe...  2016         274
# 22  Anzahl Fahrradunfälle  mit schwerverletzten Pe...  2013          33
# 23  Anzahl Fahrradunfälle  mit schwerverletzten Pe...  2014          50
# 24  Anzahl Fahrradunfälle  mit schwerverletzten Pe...  2015          52
# 25  Anzahl Fahrradunfälle  mit schwerverletzten Pe...  2016          49
# 26                         Beförderte Personen (ÖPNV)  2011  35,596,801
# 27                         Beförderte Personen (ÖPNV)  2012  35,438,793
# 28                         Beförderte Personen (ÖPNV)  2013  35,681,996
# 29                         Beförderte Personen (ÖPNV)  2014  35,539,657
# 30                         Beförderte Personen (ÖPNV)  2015  36,075,670
# 31                         Beförderte Personen (ÖPNV)  2016  36,305,605
# 32  Anzahl der Personen, die sehr und eher zufried...  2015         370
# 33  Anzahl der Personen, die eher unzufrieden und ...  2015         111
# 34             Anteil PKW an den Verkehrsmitteln in %  2013          48
# 35       Anteil Fußgänger an den Verkehrsmitteln in %  2013          24
# 36  Anzahl der Verkehrsunfälle in der Stadt Osnabrück  2010        5060
# 37  Anzahl der Verkehrsunfälle in der Stadt Osnabrück  2011        5117
# 38  Anzahl der Verkehrsunfälle in der Stadt Osnabrück  2012        5165
# 39  Anzahl der Verkehrsunfälle in der Stadt Osnabrück  2013        5331
# 40  Anzahl der Verkehrsunfälle in der Stadt Osnabrück  2014        5268
# 41  Anzahl der Verkehrsunfälle in der Stadt Osnabrück  2015        5217
# 42  Anzahl der Verkehrsunfälle in der Stadt Osnabrück  2016        4904
# 43   Anzahl der Fahrradunfälle in der Stadt Osnabrück  2013         390
# 44   Anzahl der Fahrradunfälle in der Stadt Osnabrück  2014         431
# 45   Anzahl der Fahrradunfälle in der Stadt Osnabrück  2015         434
# 46   Anzahl der Fahrradunfälle in der Stadt Osnabrück  2016         443
# 47                            PKW-Dichte (Pkw/1000EW)  2010         472
# 48                            PKW-Dichte (Pkw/1000EW)  2011         475
# 49                            PKW-Dichte (Pkw/1000EW)  2012         479
# 50                            PKW-Dichte (Pkw/1000EW)  2013         484
# 51                            PKW-Dichte (Pkw/1000EW)  2014         491
# 52                            PKW-Dichte (Pkw/1000EW)  2015         479
# 53                            PKW-Dichte (Pkw/1000EW)  2016         483
# 54                          Durchschnitt PKW/Haushalt  2014        0.77
# 55                          Durchschnitt PKW/Haushalt  2015        0.78
# 56                          Durchschnitt PKW/Haushalt  2016        0.79
# 57                          Durchschnitt PKW/Haushalt  2017         0.8
# 58            Anteil ÖPNV an den Verkehrsmitteln in %  2013           8

# %%
data['Jahr'] = pd.to_datetime(data['Jahr'].astype(str).str[:4])

# %%
try:
    data['Wert'] = pd.to_numeric(data['Wert'].astype(str))
except ValueError:
    data['Wert'] = data['Wert'].astype(str).str.replace(',', '')
    data['Wert'] = pd.to_numeric(data['Wert'])

# %%
data
# Out:
#                                  Detailziel  \
# 0            Nachhaltige Mobilitätskonzepte
# 1            Nachhaltige Mobilitätskonzepte
# 2            Nachhaltige Mobilitätskonzepte
# 3            Nachhaltige Mobilitätskonzepte
# 4            Nachhaltige Mobilitätskonzepte
# 5            Nachhaltige Mobilitätskonzepte
# 6            Nachhaltige Mobilitätskonzepte
# 7            Nachhaltige Mobilitätskonzepte
# 8            Nachhaltige Mobilitätskonzepte
# 9            Nachhaltige Mobilitätskonzepte
# 10           Nachhaltige Mobilitätskonzepte
# 11           Nachhaltige Mobilitätskonzepte
# 12           Nachhaltige Mobilitätskonzepte
# 13           Nachhaltige Mobilitätskonzepte
# 14           Nachhaltige Mobilitätskonzepte
# 15                      E-Mobilität fördern
# 16                      E-Mobilität fördern
# 17                       Radverkehr stärken
# 18                       Radverkehr stärken
# 19                       Radverkehr stärken
# 20                       Radverkehr stärken
# 21                       Radverkehr stärken
# 22                       Radverkehr stärken
# 23                       Radverkehr stärken
# 24                       Radverkehr stärken
# 25                       Radverkehr stärken
# 26  Öffentlichen Personennahverkehr fördern
# 27  Öffentlichen Personennahverkehr fördern
# 28  Öffentlichen Personennahverkehr fördern
# 29  Öffentlichen Personennahverkehr fördern
# 30  Öffentlichen Personennahverkehr fördern
# 31  Öffentlichen Personennahverkehr fördern
# 32  Öffentlichen Personennahverkehr fördern
# 33  Öffentlichen Personennahverkehr fördern
# 34                                 Weiteres
# 35                                 Weiteres
# 36                                 Weiteres
# 37                                 Weiteres
# 38                                 Weiteres
# 39                                 Weiteres
# 40                                 Weiteres
# 41                                 Weiteres
# 42                                 Weiteres
# 43                                 Weiteres
# 44                                 Weiteres
# 45                                 Weiteres
# 46                                 Weiteres
# 47                                 Weiteres
# 48                                 Weiteres
# 49                                 Weiteres
# 50                                 Weiteres
# 51                                 Weiteres
# 52                                 Weiteres
# 53                                 Weiteres
# 54                                 Weiteres
# 55                                 Weiteres
# 56                                 Weiteres
# 57                                 Weiteres
# 58                                 Weiteres
#
#                                             Indikator       Jahr         Wert
# 0                                   Carsharing Nutzer 2012-01-01       737.00
# 1                                   Carsharing Nutzer 2013-01-01       960.00
# 2                                   Carsharing Nutzer 2014-01-01      1436.00
# 3                                   Carsharing Nutzer 2015-01-01      1860.00
# 4                                   Carsharing Nutzer 2016-01-01      2409.00
# 5                         Anzahl Carsharing Fahrzeuge 2012-01-01        41.00
# 6                         Anzahl Carsharing Fahrzeuge 2013-01-01        49.00
# 7                         Anzahl Carsharing Fahrzeuge 2014-01-01        69.00
# 8                         Anzahl Carsharing Fahrzeuge 2015-01-01        86.00
# 9                         Anzahl Carsharing Fahrzeuge 2016-01-01        79.00
# 10                        Anzahl Carsharing Standorte 2012-01-01        36.00
# 11                        Anzahl Carsharing Standorte 2013-01-01        42.00
# 12                        Anzahl Carsharing Standorte 2014-01-01        44.00
# 13                        Anzahl Carsharing Standorte 2015-01-01        47.00
# 14                        Anzahl Carsharing Standorte 2016-01-01        50.00
# 15               Anteil zugelassener E-Fahrzeuge in % 2017-01-01         0.06
# 16  Anteil zugelassener Plug-In Hybride am Gesamtb... 2017-01-01         0.03
# 17      Anteil Radverkehr an den Verkehrsmitteln in % 2013-01-01        20.00
# 18  Anzahl Fahrradunfälle  mit leichtverletzten Pe... 2013-01-01       241.00
# 19  Anzahl Fahrradunfälle  mit leichtverletzten Pe... 2014-01-01       253.00
# 20  Anzahl Fahrradunfälle  mit leichtverletzten Pe... 2015-01-01       259.00
# 21  Anzahl Fahrradunfälle  mit leichtverletzten Pe... 2016-01-01       274.00
# 22  Anzahl Fahrradunfälle  mit schwerverletzten Pe... 2013-01-01        33.00
# 23  Anzahl Fahrradunfälle  mit schwerverletzten Pe... 2014-01-01        50.00
# 24  Anzahl Fahrradunfälle  mit schwerverletzten Pe... 2015-01-01        52.00
# 25  Anzahl Fahrradunfälle  mit schwerverletzten Pe... 2016-01-01        49.00
# 26                         Beförderte Personen (ÖPNV) 2011-01-01  35596801.00
# 27                         Beförderte Personen (ÖPNV) 2012-01-01  35438793.00
# 28                         Beförderte Personen (ÖPNV) 2013-01-01  35681996.00
# 29                         Beförderte Personen (ÖPNV) 2014-01-01  35539657.00
# 30                         Beförderte Personen (ÖPNV) 2015-01-01  36075670.00
# 31                         Beförderte Personen (ÖPNV) 2016-01-01  36305605.00
# 32  Anzahl der Personen, die sehr und eher zufried... 2015-01-01       370.00
# 33  Anzahl der Personen, die eher unzufrieden und ... 2015-01-01       111.00
# 34             Anteil PKW an den Verkehrsmitteln in % 2013-01-01        48.00
# 35       Anteil Fußgänger an den Verkehrsmitteln in % 2013-01-01        24.00
# 36  Anzahl der Verkehrsunfälle in der Stadt Osnabrück 2010-01-01      5060.00
# 37  Anzahl der Verkehrsunfälle in der Stadt Osnabrück 2011-01-01      5117.00
# 38  Anzahl der Verkehrsunfälle in der Stadt Osnabrück 2012-01-01      5165.00
# 39  Anzahl der Verkehrsunfälle in der Stadt Osnabrück 2013-01-01      5331.00
# 40  Anzahl der Verkehrsunfälle in der Stadt Osnabrück 2014-01-01      5268.00
# 41  Anzahl der Verkehrsunfälle in der Stadt Osnabrück 2015-01-01      5217.00
# 42  Anzahl der Verkehrsunfälle in der Stadt Osnabrück 2016-01-01      4904.00
# 43   Anzahl der Fahrradunfälle in der Stadt Osnabrück 2013-01-01       390.00
# 44   Anzahl der Fahrradunfälle in der Stadt Osnabrück 2014-01-01       431.00
# 45   Anzahl der Fahrradunfälle in der Stadt Osnabrück 2015-01-01       434.00
# 46   Anzahl der Fahrradunfälle in der Stadt Osnabrück 2016-01-01       443.00
# 47                            PKW-Dichte (Pkw/1000EW) 2010-01-01       472.00
# 48                            PKW-Dichte (Pkw/1000EW) 2011-01-01       475.00
# 49                            PKW-Dichte (Pkw/1000EW) 2012-01-01       479.00
# 50                            PKW-Dichte (Pkw/1000EW) 2013-01-01       484.00
# 51                            PKW-Dichte (Pkw/1000EW) 2014-01-01       491.00
# 52                            PKW-Dichte (Pkw/1000EW) 2015-01-01       479.00
# 53                            PKW-Dichte (Pkw/1000EW) 2016-01-01       483.00
# 54                          Durchschnitt PKW/Haushalt 2014-01-01         0.77
# 55                          Durchschnitt PKW/Haushalt 2015-01-01         0.78
# 56                          Durchschnitt PKW/Haushalt 2016-01-01         0.79
# 57                          Durchschnitt PKW/Haushalt 2017-01-01         0.80
# 58            Anteil ÖPNV an den Verkehrsmitteln in % 2013-01-01         8.00

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Data columns (total 4 columns):
# Detailziel    59 non-null object
# Indikator     59 non-null object
# Jahr          59 non-null datetime64[ns]
# Wert          59 non-null float64
# dtypes: datetime64[ns](1), float64(1), object(2)
# memory usage: 1.9+ KB

# %%
for group, subset in data.groupby('Indikator'):
    if len(subset) > 1:
        (ggplot(subset, aes(x='Jahr', y='Wert'))
         + geom_point(color='red')
         + geom_line(color='red')
         + geom_smooth(method='lm')
         + labs(title=group)
         + scale_x_date(date_breaks='1 year', date_labels='%Y')
        ).draw()
    else:
        continue

# %%
import seaborn as sns
import matplotlib.pyplot as plt
for group, subset in data.groupby('Indikator'):
    if len(subset) > 1:
        subset['Jahr_int'] = subset.Jahr.dt.year
        sns.jointplot(x='Jahr_int', y='Wert', kind='reg', data=subset)
        plt.suptitle(group)
    else:
        continue
# Out:
# /home/jarno/.miniconda/envs/scientific/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /home/jarno/.miniconda/envs/scientific/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# /home/jarno/.miniconda/envs/scientific/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# /home/jarno/.miniconda/envs/scientific/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# /home/jarno/.miniconda/envs/scientific/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# /home/jarno/.miniconda/envs/scientific/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# /home/jarno/.miniconda/envs/scientific/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# /home/jarno/.miniconda/envs/scientific/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# /home/jarno/.miniconda/envs/scientific/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# /home/jarno/.miniconda/envs/scientific/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# /home/jarno/.miniconda/envs/scientific/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# /home/jarno/.miniconda/envs/scientific/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# /home/jarno/.miniconda/envs/scientific/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# /home/jarno/.miniconda/envs/scientific/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# /home/jarno/.miniconda/envs/scientific/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# /home/jarno/.miniconda/envs/scientific/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# /home/jarno/.miniconda/envs/scientific/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# /home/jarno/.miniconda/envs/scientific/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# /home/jarno/.miniconda/envs/scientific/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# /home/jarno/.miniconda/envs/scientific/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# /home/jarno/.miniconda/envs/scientific/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# Turn each indicator into it's own column.

# %%
data = data.pivot(index='Jahr', columns='Indikator', values='Wert')
data

# %%
data
# Out:
# Indikator   Anteil Fußgänger an den Verkehrsmitteln in %  \
# Jahr
# 2010-01-01                                           NaN
# 2011-01-01                                           NaN
# 2012-01-01                                           NaN
# 2013-01-01                                          24.0
# 2014-01-01                                           NaN
# 2015-01-01                                           NaN
# 2016-01-01                                           NaN
# 2017-01-01                                           NaN
#
# Indikator   Anteil PKW an den Verkehrsmitteln in %  \
# Jahr
# 2010-01-01                                     NaN
# 2011-01-01                                     NaN
# 2012-01-01                                     NaN
# 2013-01-01                                    48.0
# 2014-01-01                                     NaN
# 2015-01-01                                     NaN
# 2016-01-01                                     NaN
# 2017-01-01                                     NaN
#
# Indikator   Anteil Radverkehr an den Verkehrsmitteln in %  \
# Jahr
# 2010-01-01                                            NaN
# 2011-01-01                                            NaN
# 2012-01-01                                            NaN
# 2013-01-01                                           20.0
# 2014-01-01                                            NaN
# 2015-01-01                                            NaN
# 2016-01-01                                            NaN
# 2017-01-01                                            NaN
#
# Indikator   Anteil zugelassener E-Fahrzeuge in %  \
# Jahr
# 2010-01-01                                   NaN
# 2011-01-01                                   NaN
# 2012-01-01                                   NaN
# 2013-01-01                                   NaN
# 2014-01-01                                   NaN
# 2015-01-01                                   NaN
# 2016-01-01                                   NaN
# 2017-01-01                                  0.06
#
# Indikator   Anteil zugelassener Plug-In Hybride am Gesamtbestand in %  \
# Jahr
# 2010-01-01                                                NaN
# 2011-01-01                                                NaN
# 2012-01-01                                                NaN
# 2013-01-01                                                NaN
# 2014-01-01                                                NaN
# 2015-01-01                                                NaN
# 2016-01-01                                                NaN
# 2017-01-01                                               0.03
#
# Indikator   Anteil ÖPNV an den Verkehrsmitteln in %  \
# Jahr
# 2010-01-01                                      NaN
# 2011-01-01                                      NaN
# 2012-01-01                                      NaN
# 2013-01-01                                      8.0
# 2014-01-01                                      NaN
# 2015-01-01                                      NaN
# 2016-01-01                                      NaN
# 2017-01-01                                      NaN
#
# Indikator   Anzahl Carsharing Fahrzeuge  Anzahl Carsharing Standorte  \
# Jahr
# 2010-01-01                          NaN                          NaN
# 2011-01-01                          NaN                          NaN
# 2012-01-01                         41.0                         36.0
# 2013-01-01                         49.0                         42.0
# 2014-01-01                         69.0                         44.0
# 2015-01-01                         86.0                         47.0
# 2016-01-01                         79.0                         50.0
# 2017-01-01                          NaN                          NaN
#
# Indikator   Anzahl Fahrradunfälle  mit leichtverletzten Personen  \
# Jahr
# 2010-01-01                                                NaN
# 2011-01-01                                                NaN
# 2012-01-01                                                NaN
# 2013-01-01                                              241.0
# 2014-01-01                                              253.0
# 2015-01-01                                              259.0
# 2016-01-01                                              274.0
# 2017-01-01                                                NaN
#
# Indikator   Anzahl Fahrradunfälle  mit schwerverletzten Personen  \
# Jahr
# 2010-01-01                                                NaN
# 2011-01-01                                                NaN
# 2012-01-01                                                NaN
# 2013-01-01                                               33.0
# 2014-01-01                                               50.0
# 2015-01-01                                               52.0
# 2016-01-01                                               49.0
# 2017-01-01                                                NaN
#
# Indikator   Anzahl der Fahrradunfälle in der Stadt Osnabrück  \
# Jahr
# 2010-01-01                                               NaN
# 2011-01-01                                               NaN
# 2012-01-01                                               NaN
# 2013-01-01                                             390.0
# 2014-01-01                                             431.0
# 2015-01-01                                             434.0
# 2016-01-01                                             443.0
# 2017-01-01                                               NaN
#
# Indikator   Anzahl der Personen, die eher unzufrieden und überhaupt nicht zufrieden mit dem öffentlichem Nahverkehr sind  \
# Jahr
# 2010-01-01                                                NaN
# 2011-01-01                                                NaN
# 2012-01-01                                                NaN
# 2013-01-01                                                NaN
# 2014-01-01                                                NaN
# 2015-01-01                                              111.0
# 2016-01-01                                                NaN
# 2017-01-01                                                NaN
#
# Indikator   Anzahl der Personen, die sehr und eher zufrieden mit dem öffentlichem Nahverkehr sind  \
# Jahr
# 2010-01-01                                                NaN
# 2011-01-01                                                NaN
# 2012-01-01                                                NaN
# 2013-01-01                                                NaN
# 2014-01-01                                                NaN
# 2015-01-01                                              370.0
# 2016-01-01                                                NaN
# 2017-01-01                                                NaN
#
# Indikator   Anzahl der Verkehrsunfälle in der Stadt Osnabrück  \
# Jahr
# 2010-01-01                                             5060.0
# 2011-01-01                                             5117.0
# 2012-01-01                                             5165.0
# 2013-01-01                                             5331.0
# 2014-01-01                                             5268.0
# 2015-01-01                                             5217.0
# 2016-01-01                                             4904.0
# 2017-01-01                                                NaN
#
# Indikator   Beförderte Personen (ÖPNV)  Carsharing Nutzer  \
# Jahr
# 2010-01-01                         NaN                NaN
# 2011-01-01                  35596801.0                NaN
# 2012-01-01                  35438793.0              737.0
# 2013-01-01                  35681996.0              960.0
# 2014-01-01                  35539657.0             1436.0
# 2015-01-01                  36075670.0             1860.0
# 2016-01-01                  36305605.0             2409.0
# 2017-01-01                         NaN                NaN
#
# Indikator   Durchschnitt PKW/Haushalt  PKW-Dichte (Pkw/1000EW)
# Jahr
# 2010-01-01                        NaN                    472.0
# 2011-01-01                        NaN                    475.0
# 2012-01-01                        NaN                    479.0
# 2013-01-01                        NaN                    484.0
# 2014-01-01                       0.77                    491.0
# 2015-01-01                       0.78                    479.0
# 2016-01-01                       0.79                    483.0
# 2017-01-01                       0.80                      NaN

# %%
data.columns
# Out:
# Index(['Anteil Fußgänger an den Verkehrsmitteln in %',
#        'Anteil PKW an den Verkehrsmitteln in %',
#        'Anteil Radverkehr an den Verkehrsmitteln in %',
#        'Anteil zugelassener E-Fahrzeuge in %',
#        'Anteil zugelassener Plug-In Hybride am Gesamtbestand in %',
#        'Anteil ÖPNV an den Verkehrsmitteln in %',
#        'Anzahl Carsharing Fahrzeuge', 'Anzahl Carsharing Standorte',
#        'Anzahl Fahrradunfälle  mit leichtverletzten Personen',
#        'Anzahl Fahrradunfälle  mit schwerverletzten Personen',
#        'Anzahl der Fahrradunfälle in der Stadt Osnabrück',
#        'Anzahl der Personen, die eher unzufrieden und überhaupt nicht zufrieden mit dem öffentlichem Nahverkehr sind',
#        'Anzahl der Personen, die sehr und eher zufrieden mit dem öffentlichem Nahverkehr sind',
#        'Anzahl der Verkehrsunfälle in der Stadt Osnabrück',
#        'Beförderte Personen (ÖPNV)', 'Carsharing Nutzer',
#        'Durchschnitt PKW/Haushalt', 'PKW-Dichte (Pkw/1000EW)'],
#       dtype='object', name='Indikator')

# %%
data['Jahr'] = data.index
data
# Out:
# Indikator   Anteil Fußgänger an den Verkehrsmitteln in %  \
# Jahr
# 2010-01-01                                           NaN
# 2011-01-01                                           NaN
# 2012-01-01                                           NaN
# 2013-01-01                                          24.0
# 2014-01-01                                           NaN
# 2015-01-01                                           NaN
# 2016-01-01                                           NaN
# 2017-01-01                                           NaN
#
# Indikator   Anteil PKW an den Verkehrsmitteln in %  \
# Jahr
# 2010-01-01                                     NaN
# 2011-01-01                                     NaN
# 2012-01-01                                     NaN
# 2013-01-01                                    48.0
# 2014-01-01                                     NaN
# 2015-01-01                                     NaN
# 2016-01-01                                     NaN
# 2017-01-01                                     NaN
#
# Indikator   Anteil Radverkehr an den Verkehrsmitteln in %  \
# Jahr
# 2010-01-01                                            NaN
# 2011-01-01                                            NaN
# 2012-01-01                                            NaN
# 2013-01-01                                           20.0
# 2014-01-01                                            NaN
# 2015-01-01                                            NaN
# 2016-01-01                                            NaN
# 2017-01-01                                            NaN
#
# Indikator   Anteil zugelassener E-Fahrzeuge in %  \
# Jahr
# 2010-01-01                                   NaN
# 2011-01-01                                   NaN
# 2012-01-01                                   NaN
# 2013-01-01                                   NaN
# 2014-01-01                                   NaN
# 2015-01-01                                   NaN
# 2016-01-01                                   NaN
# 2017-01-01                                  0.06
#
# Indikator   Anteil zugelassener Plug-In Hybride am Gesamtbestand in %  \
# Jahr
# 2010-01-01                                                NaN
# 2011-01-01                                                NaN
# 2012-01-01                                                NaN
# 2013-01-01                                                NaN
# 2014-01-01                                                NaN
# 2015-01-01                                                NaN
# 2016-01-01                                                NaN
# 2017-01-01                                               0.03
#
# Indikator   Anteil ÖPNV an den Verkehrsmitteln in %  \
# Jahr
# 2010-01-01                                      NaN
# 2011-01-01                                      NaN
# 2012-01-01                                      NaN
# 2013-01-01                                      8.0
# 2014-01-01                                      NaN
# 2015-01-01                                      NaN
# 2016-01-01                                      NaN
# 2017-01-01                                      NaN
#
# Indikator   Anzahl Carsharing Fahrzeuge  Anzahl Carsharing Standorte  \
# Jahr
# 2010-01-01                          NaN                          NaN
# 2011-01-01                          NaN                          NaN
# 2012-01-01                         41.0                         36.0
# 2013-01-01                         49.0                         42.0
# 2014-01-01                         69.0                         44.0
# 2015-01-01                         86.0                         47.0
# 2016-01-01                         79.0                         50.0
# 2017-01-01                          NaN                          NaN
#
# Indikator   Anzahl Fahrradunfälle  mit leichtverletzten Personen  \
# Jahr
# 2010-01-01                                                NaN
# 2011-01-01                                                NaN
# 2012-01-01                                                NaN
# 2013-01-01                                              241.0
# 2014-01-01                                              253.0
# 2015-01-01                                              259.0
# 2016-01-01                                              274.0
# 2017-01-01                                                NaN
#
# Indikator   Anzahl Fahrradunfälle  mit schwerverletzten Personen  \
# Jahr
# 2010-01-01                                                NaN
# 2011-01-01                                                NaN
# 2012-01-01                                                NaN
# 2013-01-01                                               33.0
# 2014-01-01                                               50.0
# 2015-01-01                                               52.0
# 2016-01-01                                               49.0
# 2017-01-01                                                NaN
#
# Indikator   Anzahl der Fahrradunfälle in der Stadt Osnabrück  \
# Jahr
# 2010-01-01                                               NaN
# 2011-01-01                                               NaN
# 2012-01-01                                               NaN
# 2013-01-01                                             390.0
# 2014-01-01                                             431.0
# 2015-01-01                                             434.0
# 2016-01-01                                             443.0
# 2017-01-01                                               NaN
#
# Indikator   Anzahl der Personen, die eher unzufrieden und überhaupt nicht zufrieden mit dem öffentlichem Nahverkehr sind  \
# Jahr
# 2010-01-01                                                NaN
# 2011-01-01                                                NaN
# 2012-01-01                                                NaN
# 2013-01-01                                                NaN
# 2014-01-01                                                NaN
# 2015-01-01                                              111.0
# 2016-01-01                                                NaN
# 2017-01-01                                                NaN
#
# Indikator   Anzahl der Personen, die sehr und eher zufrieden mit dem öffentlichem Nahverkehr sind  \
# Jahr
# 2010-01-01                                                NaN
# 2011-01-01                                                NaN
# 2012-01-01                                                NaN
# 2013-01-01                                                NaN
# 2014-01-01                                                NaN
# 2015-01-01                                              370.0
# 2016-01-01                                                NaN
# 2017-01-01                                                NaN
#
# Indikator   Anzahl der Verkehrsunfälle in der Stadt Osnabrück  \
# Jahr
# 2010-01-01                                             5060.0
# 2011-01-01                                             5117.0
# 2012-01-01                                             5165.0
# 2013-01-01                                             5331.0
# 2014-01-01                                             5268.0
# 2015-01-01                                             5217.0
# 2016-01-01                                             4904.0
# 2017-01-01                                                NaN
#
# Indikator   Beförderte Personen (ÖPNV)  Carsharing Nutzer  \
# Jahr
# 2010-01-01                         NaN                NaN
# 2011-01-01                  35596801.0                NaN
# 2012-01-01                  35438793.0              737.0
# 2013-01-01                  35681996.0              960.0
# 2014-01-01                  35539657.0             1436.0
# 2015-01-01                  36075670.0             1860.0
# 2016-01-01                  36305605.0             2409.0
# 2017-01-01                         NaN                NaN
#
# Indikator   Durchschnitt PKW/Haushalt  PKW-Dichte (Pkw/1000EW)       Jahr
# Jahr
# 2010-01-01                        NaN                    472.0 2010-01-01
# 2011-01-01                        NaN                    475.0 2011-01-01
# 2012-01-01                        NaN                    479.0 2012-01-01
# 2013-01-01                        NaN                    484.0 2013-01-01
# 2014-01-01                       0.77                    491.0 2014-01-01
# 2015-01-01                       0.78                    479.0 2015-01-01
# 2016-01-01                       0.79                    483.0 2016-01-01
# 2017-01-01                       0.80                      NaN 2017-01-01

# %%
with warnings.catch_warnings():
    warnings.simplefilter("ignore")

    for kennzahl in data.columns:
        (ggplot(data, aes(x='data.index', y=kennzahl))
                 + geom_point(color='red', na_rm=True)
                 + geom_line(color='red')
                 + geom_smooth(method='lm')
                 + scale_x_date(date_breaks='1 year', date_labels='%Y')
        ).draw()

# %%
data['jahr_int'] = data.index.year

# %%
data.index.year
# Out:
# Int64Index([2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017], dtype='int64', name='Jahr')

# %%
with warnings.catch_warnings():
    warnings.simplefilter("ignore")

    for kennzahl in data.columns:
        sns.jointplot(x='jahr_int', y=kennzahl, kind='reg', data=data)
#         plt.suptitle(group)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-e5b660462dc7> in <module>()
#       3
#       4     for kennzahl in data.columns:
# ----> 5         sns.jointplot(x='jahr_int', y=kennzahl, kind='reg', data=data)
#       6 #         plt.suptitle(group)
#
# ~/.miniconda/envs/scientific/lib/python3.6/site-packages/seaborn/axisgrid.py in jointplot(x, y, data, kind, stat_func, color, size, ratio, space, dropna, xlim, ylim, joint_kws, marginal_kws, annot_kws, **kwargs)
#    2280
#    2281         marginal_kws.setdefault("color", color)
# -> 2282         grid.plot_marginals(distplot, **marginal_kws)
#    2283
#    2284         joint_kws.setdefault("color", color)
#
# ~/.miniconda/envs/scientific/lib/python3.6/site-packages/seaborn/axisgrid.py in plot_marginals(self, func, **kwargs)
#    1782         kwargs["vertical"] = True
#    1783         plt.sca(self.ax_marg_y)
# -> 1784         func(self.y, **kwargs)
#    1785
#    1786         return self
#
# ~/.miniconda/envs/scientific/lib/python3.6/site-packages/seaborn/distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     210     if hist:
#     211         if bins is None:
# --> 212             bins = min(_freedman_diaconis_bins(a), 50)
#     213         hist_kws.setdefault("alpha", 0.4)
#     214         hist_kws.setdefault("normed", norm_hist)
#
# ~/.miniconda/envs/scientific/lib/python3.6/site-packages/seaborn/distributions.py in _freedman_diaconis_bins(a)
#      29     if len(a) < 2:
#      30         return 1
# ---> 31     h = 2 * iqr(a) / (len(a) ** (1 / 3))
#      32     # fall back to sqrt(a) bins if iqr is 0
#      33     if h == 0:
#
# ~/.miniconda/envs/scientific/lib/python3.6/site-packages/seaborn/utils.py in iqr(a)
#     346     """Calculate the IQR for an array of numbers."""
#     347     a = np.asarray(a)
# --> 348     q1 = stats.scoreatpercentile(a, 25)
#     349     q3 = stats.scoreatpercentile(a, 75)
#     350     return q3 - q1
#
# ~/.miniconda/envs/scientific/lib/python3.6/site-packages/scipy/stats/stats.py in scoreatpercentile(a, per, limit, interpolation_method, axis)
#    1661         axis = 0
#    1662
# -> 1663     return _compute_qth_percentile(sorted, per, interpolation_method, axis)
#    1664
#    1665
#
# ~/.miniconda/envs/scientific/lib/python3.6/site-packages/scipy/stats/stats.py in _compute_qth_percentile(sorted, per, interpolation_method, axis)
#    1704
#    1705     # Use np.add.reduce (== np.sum but a little faster) to coerce data type
# -> 1706     return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
#    1707
#    1708
#
# TypeError: ufunc multiply cannot use operands with types dtype('<M8[ns]') and dtype('float64')

# %%
for group, subset in data.groupby('Indikator'):
    if len(subset) > 1:
        (ggplot(subset, aes(x='Jahr', y='Wert'))
         + geom_point(color='red')
         + geom_line(color='red')
         + geom_smooth(method='lm')
         + labs(title=group)
         + scale_x_date(date_breaks='1 year', date_labels='%Y')
        ).draw()
    else:
        continue

# %%
corr = data.corr()
# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
